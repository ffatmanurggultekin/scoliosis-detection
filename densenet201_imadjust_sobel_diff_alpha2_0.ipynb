# %% [markdown]
# <a href="https://colab.research.google.com/github/ffatmanurggultekin/scoliosis-detection/blob/main/densenet201_imadjust_sobel_diff_alpha2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#############################################
# 1) Klasör Yolları ve Ayarlar
#############################################
train_dir = "/content/drive/MyDrive/train_imadjust_sobel_diff_alpha2.0"
val_dir = "/content/drive/MyDrive/validation_imadjust_sobel_diff_alpha2.0"

batch_size = 32
epochs = 50
n_splits = 5  # Cross-validation kat sayısı

# %%
#############################################
# 2) Veri Yollarını ve Etiketlerini Toplama
#############################################
def gather_paths_and_labels(dir_path):
    filepaths = []
    labels = []

    normal_path = os.path.join(dir_path, "Normal")
    scol_path = os.path.join(dir_path, "Scol")

    if os.path.exists(normal_path):
        for fname in os.listdir(normal_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(normal_path, fname))
                labels.append(0)  # Normal => 0

    if os.path.exists(scol_path):
        for fname in os.listdir(scol_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(scol_path, fname))
                labels.append(1)  # Scol => 1

    return pd.DataFrame({'filepath': filepaths, 'label': labels})

# Train ve Validation'dan gelen DataFrame'leri birleştirelim
df_train = gather_paths_and_labels(train_dir)
df_val = gather_paths_and_labels(val_dir)
df_trainVal = pd.concat([df_train, df_val], ignore_index=True)

# Label sütununu string formatına çevir
df_trainVal['label'] = df_trainVal['label'].astype(str)

print(f"Train+Validation birleşik boyutu: {len(df_trainVal)}")
# Out:
# Train+Validation birleşik boyutu: 214

# %%
#############################################
# 3) DenseNet201 Modelini Oluşturma
#############################################
def create_densenet201_model():
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers:
        layer.trainable = False  # Fine-tuning yapmayacaksanız dondurun

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=base_model.input, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
#############################################
# 4) Cross-Validation Fonksiyonu
#############################################
def run_5fold_cv(df, n_splits=5, epochs=50, batch_size=32):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    X = df['filepath'].values
    y = df['label'].values

    accuracy_list = []
    precision_list = []
    recall_list = []
    f1_list = []
    fold_no = 1

    # Data Augmentation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    val_datagen = ImageDataGenerator(rescale=1./255)

    for train_idx, val_idx in skf.split(X, y):
        print(f"\n=== Fold {fold_no}/{n_splits} ===")

        # Fold için Train/Validation veri setlerini ayır
        train_fold = df.iloc[train_idx]
        val_fold = df.iloc[val_idx]

        # Data generator'lar
        train_gen = train_datagen.flow_from_dataframe(
            train_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )
        val_gen = val_datagen.flow_from_dataframe(
            val_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )

        # Modeli oluştur
        model = create_densenet201_model()

        # EarlyStopping
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        steps_per_epoch = math.ceil(len(train_fold) / batch_size)
        validation_steps = math.ceil(len(val_fold) / batch_size)

        # Modeli eğit
        history = model.fit(
            train_gen,
            epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            validation_data=val_gen,
            validation_steps=validation_steps,
            callbacks=[early_stopping],
            verbose=1
        )

        # Validation setinde değerlendirme
        val_loss, val_acc = model.evaluate(val_gen, steps=validation_steps, verbose=0)
        accuracy_list.append(val_acc)

        # Confusion Matrix ve Classification Report
        y_val_pred_prob = model.predict(val_gen, steps=validation_steps, verbose=0)
        y_val_pred = (y_val_pred_prob > 0.5).astype(int).ravel()
        y_val_true = val_fold['label'].astype(int).values

        precision = precision_score(y_val_true, y_val_pred, average='binary')
        recall = recall_score(y_val_true, y_val_pred, average='binary')
        f1 = f1_score(y_val_true, y_val_pred, average='binary')

        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

        print("\nValidation Metrics:")
        print(f"Accuracy: {val_acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

        fold_no += 1

    mean_acc = np.mean(accuracy_list)
    mean_precision = np.mean(precision_list)
    mean_recall = np.mean(recall_list)
    mean_f1 = np.mean(f1_list)

    print("\n5-Fold CV Metrics:")
    print(f"Mean Accuracy: {mean_acc:.4f}")
    print(f"Mean Precision: {mean_precision:.4f}")
    print(f"Mean Recall: {mean_recall:.4f}")
    print(f"Mean F1-Score: {mean_f1:.4f}")

    return mean_acc, mean_precision, mean_recall, mean_f1

# %%
#############################################
# 5) 5-Fold Cross-Validation'ı Çalıştır
#############################################
mean_acc, mean_precision, mean_recall, mean_f1 = run_5fold_cv(df_trainVal, n_splits=n_splits, epochs=epochs, batch_size=batch_size)
print(f"\nFinal Results:\nAccuracy = {mean_acc:.4f}, Precision = {mean_precision:.4f}, Recall = {mean_recall:.4f}, F1-Score = {mean_f1:.4f}")
# Out:
# === Fold 1/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 118s 11s/step - accuracy: 0.3868 - loss: 0.9170 - val_accuracy: 0.7209 - val_loss: 0.5444
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.7126 - loss: 0.5985 - val_accuracy: 0.7209 - val_loss: 0.6051
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.7222 - loss: 0.6250 - val_accuracy: 0.7209 - val_loss: 0.5672
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.6761 - loss: 0.7457 - val_accuracy: 0.7209 - val_loss: 0.4718
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.6756 - loss: 0.6051 - val_accuracy: 0.7442 - val_loss: 0.4285
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7488 - loss: 0.4486 - val_accuracy: 0.7674 - val_loss: 0.4148
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7196 - loss: 0.5125 - val_accuracy: 0.7674 - val_loss: 0.4076
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.6720 - loss: 0.5599 - val_accuracy: 0.7209 - val_loss: 0.4114
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.7581 - loss: 0.4504 - val_accuracy: 0.7209 - val_loss: 0.4127
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.7952 - loss: 0.4260 - val_accuracy: 0.7209 - val_loss: 0.4104
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7488 - loss: 0.4722 - val_accuracy: 0.7209 - val_loss: 0.3955
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7433 - loss: 0.4681 - val_accuracy: 0.7674 - val_loss: 0.3855
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.7820 - loss: 0.4376 - val_accuracy: 0.7674 - val_loss: 0.3833
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.7976 - loss: 0.4345 - val_accuracy: 0.7209 - val_loss: 0.3954
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.7961 - loss: 0.3928 - val_accuracy: 0.7209 - val_loss: 0.3895
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.7843 - loss: 0.3941 - val_accuracy: 0.7209 - val_loss: 0.3895
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8612 - loss: 0.3489 - val_accuracy: 0.7907 - val_loss: 0.3688
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.7941 - loss: 0.4034 - val_accuracy: 0.7674 - val_loss: 0.3492
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.8421 - loss: 0.3313 - val_accuracy: 0.7907 - val_loss: 0.3544
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7645 - loss: 0.4253 - val_accuracy: 0.7907 - val_loss: 0.3481
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7592 - loss: 0.4081 - val_accuracy: 0.7907 - val_loss: 0.3444
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.8222 - loss: 0.4290 - val_accuracy: 0.8140 - val_loss: 0.3338
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8131 - loss: 0.3772 - val_accuracy: 0.8372 - val_loss: 0.3332
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7953 - loss: 0.3957 - val_accuracy: 0.8140 - val_loss: 0.3264
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8661 - loss: 0.3294 - val_accuracy: 0.8140 - val_loss: 0.3281
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.8140, Precision: 0.7143, Recall: 0.8065, F1-Score: 0.7576
#
# === Fold 2/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 63s 6s/step - accuracy: 0.4296 - loss: 0.9139 - val_accuracy: 0.7209 - val_loss: 0.5726
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.7581 - loss: 0.5527 - val_accuracy: 0.7209 - val_loss: 0.6332
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7109 - loss: 0.6106 - val_accuracy: 0.7209 - val_loss: 0.5846
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7321 - loss: 0.5184 - val_accuracy: 0.6977 - val_loss: 0.5291
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7338 - loss: 0.4546 - val_accuracy: 0.6977 - val_loss: 0.5100
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7832 - loss: 0.4581 - val_accuracy: 0.6977 - val_loss: 0.5010
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7862 - loss: 0.4311 - val_accuracy: 0.6977 - val_loss: 0.5109
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.7511 - loss: 0.4728 - val_accuracy: 0.6977 - val_loss: 0.5160
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.7591 - loss: 0.4337 - val_accuracy: 0.6977 - val_loss: 0.5057
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.7236 - loss: 0.4551 - val_accuracy: 0.6977 - val_loss: 0.4945
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7510 - loss: 0.4682 - val_accuracy: 0.7442 - val_loss: 0.4815
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7528 - loss: 0.4146 - val_accuracy: 0.6977 - val_loss: 0.4873
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8081 - loss: 0.3700 - val_accuracy: 0.7209 - val_loss: 0.4968
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.7827 - loss: 0.4407 - val_accuracy: 0.7209 - val_loss: 0.4968
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8216 - loss: 0.4014 - val_accuracy: 0.7209 - val_loss: 0.4877
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.7833 - loss: 0.4365 - val_accuracy: 0.7674 - val_loss: 0.4653
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8755 - loss: 0.3431 - val_accuracy: 0.7442 - val_loss: 0.4719
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8183 - loss: 0.3527 - val_accuracy: 0.7442 - val_loss: 0.4780
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.8039 - loss: 0.3843 - val_accuracy: 0.7907 - val_loss: 0.4582
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.7466 - loss: 0.4129 - val_accuracy: 0.7674 - val_loss: 0.4644
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.8110 - loss: 0.4005 - val_accuracy: 0.7209 - val_loss: 0.4949
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.7839 - loss: 0.3705 - val_accuracy: 0.7209 - val_loss: 0.4912
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8531 - loss: 0.3145 - val_accuracy: 0.7442 - val_loss: 0.4898
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.8912 - loss: 0.2956 - val_accuracy: 0.7674 - val_loss: 0.4678
#
# Validation Metrics:
# Accuracy: 0.7907, Precision: 0.7368, Recall: 0.9032, F1-Score: 0.8116
#
# === Fold 3/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 62s 6s/step - accuracy: 0.5989 - loss: 0.6879 - val_accuracy: 0.7209 - val_loss: 0.5625
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7471 - loss: 0.5917 - val_accuracy: 0.7209 - val_loss: 0.5405
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.6964 - loss: 0.5290 - val_accuracy: 0.7209 - val_loss: 0.5155
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7424 - loss: 0.4834 - val_accuracy: 0.7674 - val_loss: 0.5067
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.7704 - loss: 0.4524 - val_accuracy: 0.7907 - val_loss: 0.4981
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.7716 - loss: 0.4602 - val_accuracy: 0.8140 - val_loss: 0.4946
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.7683 - loss: 0.5217 - val_accuracy: 0.7209 - val_loss: 0.4940
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.7456 - loss: 0.4951 - val_accuracy: 0.8140 - val_loss: 0.4851
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7755 - loss: 0.4574 - val_accuracy: 0.7907 - val_loss: 0.4801
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7336 - loss: 0.4559 - val_accuracy: 0.8140 - val_loss: 0.4775
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.7995 - loss: 0.4263 - val_accuracy: 0.8140 - val_loss: 0.4666
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.7634 - loss: 0.4305 - val_accuracy: 0.8140 - val_loss: 0.4590
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.7842 - loss: 0.4324 - val_accuracy: 0.8140 - val_loss: 0.4501
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8209 - loss: 0.4211 - val_accuracy: 0.8372 - val_loss: 0.4446
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7329 - loss: 0.4244 - val_accuracy: 0.8372 - val_loss: 0.4427
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7180 - loss: 0.4816 - val_accuracy: 0.8372 - val_loss: 0.4356
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.8019 - loss: 0.3817 - val_accuracy: 0.8372 - val_loss: 0.4369
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8072 - loss: 0.3937 - val_accuracy: 0.8372 - val_loss: 0.4276
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7907 - loss: 0.3769 - val_accuracy: 0.8372 - val_loss: 0.4116
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8249 - loss: 0.3739 - val_accuracy: 0.8140 - val_loss: 0.4065
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.7651 - loss: 0.4113 - val_accuracy: 0.8605 - val_loss: 0.4023
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8121 - loss: 0.4178 - val_accuracy: 0.8605 - val_loss: 0.3937
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8229 - loss: 0.3597 - val_accuracy: 0.8605 - val_loss: 0.3880
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8331 - loss: 0.3791 - val_accuracy: 0.8837 - val_loss: 0.3822
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8083 - loss: 0.3745 - val_accuracy: 0.8605 - val_loss: 0.3809
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b5a8c05f740> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b5a8c05f740> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Validation Metrics:
# Accuracy: 0.8605, Precision: 0.7838, Recall: 0.9355, F1-Score: 0.8529
#
# === Fold 4/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.4036 - loss: 0.9880 - val_accuracy: 0.7209 - val_loss: 0.5840
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.6743 - loss: 0.6801 - val_accuracy: 0.7209 - val_loss: 0.6000
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.6921 - loss: 0.6638 - val_accuracy: 0.7209 - val_loss: 0.5761
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.6837 - loss: 0.5648 - val_accuracy: 0.7209 - val_loss: 0.5308
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7315 - loss: 0.5329 - val_accuracy: 0.7209 - val_loss: 0.5093
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7253 - loss: 0.4815 - val_accuracy: 0.7209 - val_loss: 0.5008
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.7836 - loss: 0.4466 - val_accuracy: 0.7442 - val_loss: 0.5038
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7157 - loss: 0.5604 - val_accuracy: 0.7674 - val_loss: 0.4978
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7598 - loss: 0.4487 - val_accuracy: 0.7442 - val_loss: 0.4916
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7115 - loss: 0.4620 - val_accuracy: 0.7907 - val_loss: 0.4834
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8068 - loss: 0.4260 - val_accuracy: 0.7907 - val_loss: 0.4826
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.8095 - loss: 0.3878 - val_accuracy: 0.8372 - val_loss: 0.4690
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8116 - loss: 0.4089 - val_accuracy: 0.7674 - val_loss: 0.4553
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.8419 - loss: 0.3580 - val_accuracy: 0.8372 - val_loss: 0.4554
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.8315 - loss: 0.3725 - val_accuracy: 0.7907 - val_loss: 0.4609
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8169 - loss: 0.4184 - val_accuracy: 0.7907 - val_loss: 0.4572
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7793 - loss: 0.4243 - val_accuracy: 0.8140 - val_loss: 0.4439
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8245 - loss: 0.3276 - val_accuracy: 0.8140 - val_loss: 0.4391
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.8162 - loss: 0.4187 - val_accuracy: 0.8372 - val_loss: 0.4280
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8215 - loss: 0.3527 - val_accuracy: 0.8140 - val_loss: 0.4222
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8346 - loss: 0.3443 - val_accuracy: 0.8140 - val_loss: 0.4358
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7864 - loss: 0.3961 - val_accuracy: 0.8140 - val_loss: 0.4254
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7801 - loss: 0.4025 - val_accuracy: 0.8140 - val_loss: 0.4102
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.8137 - loss: 0.4312 - val_accuracy: 0.8140 - val_loss: 0.4023
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8242 - loss: 0.3851 - val_accuracy: 0.8140 - val_loss: 0.4031
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.8140, Precision: 0.7436, Recall: 0.9355, F1-Score: 0.8286
#
# === Fold 5/5 ===
# Found 172 validated image filenames belonging to 2 classes.
# Found 42 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 84s 10s/step - accuracy: 0.4474 - loss: 0.9859 - val_accuracy: 0.7619 - val_loss: 0.5553
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7005 - loss: 0.6213 - val_accuracy: 0.7381 - val_loss: 0.5447
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7088 - loss: 0.7218 - val_accuracy: 0.7381 - val_loss: 0.4898
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7179 - loss: 0.6154 - val_accuracy: 0.7619 - val_loss: 0.4644
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.7417 - loss: 0.4754 - val_accuracy: 0.7381 - val_loss: 0.4774
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.6883 - loss: 0.5373 - val_accuracy: 0.7619 - val_loss: 0.4541
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.6904 - loss: 0.5206 - val_accuracy: 0.8095 - val_loss: 0.4244
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7189 - loss: 0.5023 - val_accuracy: 0.8095 - val_loss: 0.4095
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.7859 - loss: 0.4572 - val_accuracy: 0.7857 - val_loss: 0.4015
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7419 - loss: 0.4489 - val_accuracy: 0.8095 - val_loss: 0.3951
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.7650 - loss: 0.4641 - val_accuracy: 0.8095 - val_loss: 0.3890
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8161 - loss: 0.4067 - val_accuracy: 0.8095 - val_loss: 0.3813
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8424 - loss: 0.3601 - val_accuracy: 0.8095 - val_loss: 0.3750
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8427 - loss: 0.4090 - val_accuracy: 0.7857 - val_loss: 0.3732
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7336 - loss: 0.4443 - val_accuracy: 0.7857 - val_loss: 0.3713
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8474 - loss: 0.3276 - val_accuracy: 0.7857 - val_loss: 0.3670
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8022 - loss: 0.3557 - val_accuracy: 0.7857 - val_loss: 0.3632
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8548 - loss: 0.3183 - val_accuracy: 0.7857 - val_loss: 0.3583
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8368 - loss: 0.3798 - val_accuracy: 0.8333 - val_loss: 0.3549
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.8036 - loss: 0.3539 - val_accuracy: 0.8095 - val_loss: 0.3492
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8112 - loss: 0.3949 - val_accuracy: 0.8095 - val_loss: 0.3460
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8860 - loss: 0.3250 - val_accuracy: 0.8095 - val_loss: 0.3451
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8460 - loss: 0.3270 - val_accuracy: 0.7857 - val_loss: 0.3455
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8085 - loss: 0.3485 - val_accuracy: 0.8095 - val_loss: 0.3391
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8805 - loss: 0.3193 - val_accuracy: 0.8095 - val_loss: 0.3359
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.8095, Precision: 0.7027, Recall: 0.8387, F1-Score: 0.7647
#
# 5-Fold CV Metrics:
# Mean Accuracy: 0.8177
# Mean Precision: 0.7362
# Mean Recall: 0.8839
# Mean F1-Score: 0.8031
#
# Final Results:
# Accuracy = 0.8177, Precision = 0.7362, Recall = 0.8839, F1-Score = 0.8031
