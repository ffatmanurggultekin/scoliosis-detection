# %% [markdown]
# <a href="https://colab.research.google.com/github/ffatmanurggultekin/scoliosis-detection/blob/main/densenet201_clahe_sobel_diff_alpha1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#############################################
# 1) Klasör Yolları ve Ayarlar
#############################################
train_dir = "/content/drive/MyDrive/train_clahe_sobel_diff_alpha1.0"
val_dir = "/content/drive/MyDrive/validation_clahe_sobel_diff_alpha1.0"

batch_size = 32
epochs = 50
n_splits = 5  # Cross-validation kat sayısı

# %%
#############################################
# 2) Veri Yollarını ve Etiketlerini Toplama
#############################################
def gather_paths_and_labels(dir_path):
    filepaths = []
    labels = []

    normal_path = os.path.join(dir_path, "Normal")
    scol_path = os.path.join(dir_path, "Scol")

    if os.path.exists(normal_path):
        for fname in os.listdir(normal_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(normal_path, fname))
                labels.append(0)  # Normal => 0

    if os.path.exists(scol_path):
        for fname in os.listdir(scol_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(scol_path, fname))
                labels.append(1)  # Scol => 1

    return pd.DataFrame({'filepath': filepaths, 'label': labels})

# Train ve Validation'dan gelen DataFrame'leri birleştirelim
df_train = gather_paths_and_labels(train_dir)
df_val = gather_paths_and_labels(val_dir)
df_trainVal = pd.concat([df_train, df_val], ignore_index=True)

# Label sütununu string formatına çevir
df_trainVal['label'] = df_trainVal['label'].astype(str)

print(f"Train+Validation birleşik boyutu: {len(df_trainVal)}")
# Out:
# Train+Validation birleşik boyutu: 214

# %%
#############################################
# 3) DenseNet201 Modelini Oluşturma
#############################################
def create_densenet201_model():
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers:
        layer.trainable = False  # Fine-tuning yapmayacaksanız dondurun

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=base_model.input, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
#############################################
# 4) Cross-Validation Fonksiyonu
#############################################
def run_5fold_cv(df, n_splits=5, epochs=50, batch_size=32):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    X = df['filepath'].values
    y = df['label'].values

    accuracy_list = []
    precision_list = []
    recall_list = []
    f1_list = []
    fold_no = 1

    # Data Augmentation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    val_datagen = ImageDataGenerator(rescale=1./255)

    for train_idx, val_idx in skf.split(X, y):
        print(f"\n=== Fold {fold_no}/{n_splits} ===")

        # Fold için Train/Validation veri setlerini ayır
        train_fold = df.iloc[train_idx]
        val_fold = df.iloc[val_idx]

        # Data generator'lar
        train_gen = train_datagen.flow_from_dataframe(
            train_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )
        val_gen = val_datagen.flow_from_dataframe(
            val_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )

        # Modeli oluştur
        model = create_densenet201_model()

        # EarlyStopping
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        steps_per_epoch = math.ceil(len(train_fold) / batch_size)
        validation_steps = math.ceil(len(val_fold) / batch_size)

        # Modeli eğit
        history = model.fit(
            train_gen,
            epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            validation_data=val_gen,
            validation_steps=validation_steps,
            callbacks=[early_stopping],
            verbose=1
        )

        # Validation setinde değerlendirme
        val_loss, val_acc = model.evaluate(val_gen, steps=validation_steps, verbose=0)
        accuracy_list.append(val_acc)

        # Confusion Matrix ve Classification Report
        y_val_pred_prob = model.predict(val_gen, steps=validation_steps, verbose=0)
        y_val_pred = (y_val_pred_prob > 0.5).astype(int).ravel()
        y_val_true = val_fold['label'].astype(int).values

        precision = precision_score(y_val_true, y_val_pred, average='binary')
        recall = recall_score(y_val_true, y_val_pred, average='binary')
        f1 = f1_score(y_val_true, y_val_pred, average='binary')

        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

        print("\nValidation Metrics:")
        print(f"Accuracy: {val_acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

        fold_no += 1

    mean_acc = np.mean(accuracy_list)
    mean_precision = np.mean(precision_list)
    mean_recall = np.mean(recall_list)
    mean_f1 = np.mean(f1_list)

    print("\n5-Fold CV Metrics:")
    print(f"Mean Accuracy: {mean_acc:.4f}")
    print(f"Mean Precision: {mean_precision:.4f}")
    print(f"Mean Recall: {mean_recall:.4f}")
    print(f"Mean F1-Score: {mean_f1:.4f}")

    return mean_acc, mean_precision, mean_recall, mean_f1

# %%
#############################################
# 5) 5-Fold Cross-Validation'ı Çalıştır
#############################################
mean_acc, mean_precision, mean_recall, mean_f1 = run_5fold_cv(df_trainVal, n_splits=n_splits, epochs=epochs, batch_size=batch_size)
print(f"\nFinal Results:\nAccuracy = {mean_acc:.4f}, Precision = {mean_precision:.4f}, Recall = {mean_recall:.4f}, F1-Score = {mean_f1:.4f}")
# Out:
# === Fold 1/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 92s 8s/step - accuracy: 0.5928 - loss: 0.6744 - val_accuracy: 0.7674 - val_loss: 0.5057
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7509 - loss: 0.5387 - val_accuracy: 0.7442 - val_loss: 0.5076
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7220 - loss: 0.5595 - val_accuracy: 0.7674 - val_loss: 0.4759
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7793 - loss: 0.4569 - val_accuracy: 0.7674 - val_loss: 0.4374
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8421 - loss: 0.4069 - val_accuracy: 0.7674 - val_loss: 0.4184
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8354 - loss: 0.3388 - val_accuracy: 0.7674 - val_loss: 0.4351
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.8506 - loss: 0.3518 - val_accuracy: 0.7674 - val_loss: 0.4671
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.7828 - loss: 0.4314 - val_accuracy: 0.7674 - val_loss: 0.4490
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8595 - loss: 0.3345 - val_accuracy: 0.7674 - val_loss: 0.4442
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8434 - loss: 0.3393 - val_accuracy: 0.7907 - val_loss: 0.3879
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8561 - loss: 0.3782 - val_accuracy: 0.8140 - val_loss: 0.3308
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8422 - loss: 0.4103 - val_accuracy: 0.8140 - val_loss: 0.3348
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.8785 - loss: 0.3324 - val_accuracy: 0.8140 - val_loss: 0.3170
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8631 - loss: 0.2702 - val_accuracy: 0.8140 - val_loss: 0.3080
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8917 - loss: 0.2569 - val_accuracy: 0.8140 - val_loss: 0.3097
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8489 - loss: 0.3062 - val_accuracy: 0.8140 - val_loss: 0.3215
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.9047 - loss: 0.2356 - val_accuracy: 0.8140 - val_loss: 0.3069
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.8766 - loss: 0.2578 - val_accuracy: 0.8140 - val_loss: 0.2894
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.9356 - loss: 0.2515 - val_accuracy: 0.8372 - val_loss: 0.2756
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.8815 - loss: 0.2734 - val_accuracy: 0.8372 - val_loss: 0.2820
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.9067 - loss: 0.2431 - val_accuracy: 0.8372 - val_loss: 0.2730
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.9053 - loss: 0.2194 - val_accuracy: 0.8605 - val_loss: 0.2604
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9481 - loss: 0.2028 - val_accuracy: 0.8605 - val_loss: 0.2591
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8890 - loss: 0.2812 - val_accuracy: 0.8605 - val_loss: 0.2547
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9209 - loss: 0.2180 - val_accuracy: 0.8372 - val_loss: 0.2686
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.8605, Precision: 0.7027, Recall: 0.8387, F1-Score: 0.7647
#
# === Fold 2/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.7307 - loss: 0.6421 - val_accuracy: 0.7209 - val_loss: 0.5477
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.6997 - loss: 0.6305 - val_accuracy: 0.7442 - val_loss: 0.4995
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7103 - loss: 0.6062 - val_accuracy: 0.7442 - val_loss: 0.4805
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7739 - loss: 0.4695 - val_accuracy: 0.7442 - val_loss: 0.4720
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8247 - loss: 0.3616 - val_accuracy: 0.7674 - val_loss: 0.4703
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8421 - loss: 0.3880 - val_accuracy: 0.7674 - val_loss: 0.4453
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8194 - loss: 0.3595 - val_accuracy: 0.7907 - val_loss: 0.4147
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8812 - loss: 0.3188 - val_accuracy: 0.7907 - val_loss: 0.4125
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8297 - loss: 0.3611 - val_accuracy: 0.7907 - val_loss: 0.4125
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8917 - loss: 0.3066 - val_accuracy: 0.7907 - val_loss: 0.4062
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8932 - loss: 0.3089 - val_accuracy: 0.8372 - val_loss: 0.3942
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8498 - loss: 0.3042 - val_accuracy: 0.8605 - val_loss: 0.3689
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8281 - loss: 0.3289 - val_accuracy: 0.8605 - val_loss: 0.3541
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8597 - loss: 0.3196 - val_accuracy: 0.8605 - val_loss: 0.3473
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.8828 - loss: 0.2636 - val_accuracy: 0.8372 - val_loss: 0.3667
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8939 - loss: 0.2655 - val_accuracy: 0.8372 - val_loss: 0.3705
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8288 - loss: 0.3118 - val_accuracy: 0.8605 - val_loss: 0.3359
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8616 - loss: 0.2943 - val_accuracy: 0.8837 - val_loss: 0.3157
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8836 - loss: 0.2683 - val_accuracy: 0.8837 - val_loss: 0.3112
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8977 - loss: 0.2455 - val_accuracy: 0.8837 - val_loss: 0.3191
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8936 - loss: 0.2792 - val_accuracy: 0.9070 - val_loss: 0.3242
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9421 - loss: 0.2056 - val_accuracy: 0.9070 - val_loss: 0.3008
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8782 - loss: 0.3006 - val_accuracy: 0.9070 - val_loss: 0.2830
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9229 - loss: 0.2315 - val_accuracy: 0.9070 - val_loss: 0.2912
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9056 - loss: 0.2121 - val_accuracy: 0.9070 - val_loss: 0.3013
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9070, Precision: 0.6970, Recall: 0.7419, F1-Score: 0.7188
#
# === Fold 3/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.4687 - loss: 0.8536 - val_accuracy: 0.7209 - val_loss: 0.5837
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.6886 - loss: 0.6893 - val_accuracy: 0.7209 - val_loss: 0.5534
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7120 - loss: 0.5908 - val_accuracy: 0.7209 - val_loss: 0.4760
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.7327 - loss: 0.4770 - val_accuracy: 0.7209 - val_loss: 0.4541
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.7949 - loss: 0.4149 - val_accuracy: 0.7209 - val_loss: 0.4386
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.7722 - loss: 0.4190 - val_accuracy: 0.7209 - val_loss: 0.4210
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8381 - loss: 0.3807 - val_accuracy: 0.7209 - val_loss: 0.4359
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8370 - loss: 0.3569 - val_accuracy: 0.7209 - val_loss: 0.4512
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7726 - loss: 0.4268 - val_accuracy: 0.7209 - val_loss: 0.4347
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8702 - loss: 0.3323 - val_accuracy: 0.7209 - val_loss: 0.3965
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.7838 - loss: 0.4026 - val_accuracy: 0.8140 - val_loss: 0.3586
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8815 - loss: 0.2822 - val_accuracy: 0.7907 - val_loss: 0.3587
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.8508 - loss: 0.2755 - val_accuracy: 0.7442 - val_loss: 0.3699
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8564 - loss: 0.3250 - val_accuracy: 0.8605 - val_loss: 0.3197
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8343 - loss: 0.2938 - val_accuracy: 0.8605 - val_loss: 0.2951
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8661 - loss: 0.3125 - val_accuracy: 0.8605 - val_loss: 0.3136
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8591 - loss: 0.2924 - val_accuracy: 0.8605 - val_loss: 0.2935
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8689 - loss: 0.2757 - val_accuracy: 0.8837 - val_loss: 0.2709
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9031 - loss: 0.2602 - val_accuracy: 0.8837 - val_loss: 0.2770
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8527 - loss: 0.2956 - val_accuracy: 0.8605 - val_loss: 0.2828
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8877 - loss: 0.2792 - val_accuracy: 0.8837 - val_loss: 0.2715
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8512 - loss: 0.2860 - val_accuracy: 0.9070 - val_loss: 0.2323
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8801 - loss: 0.3095 - val_accuracy: 0.9302 - val_loss: 0.2195
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8959 - loss: 0.2395 - val_accuracy: 0.9070 - val_loss: 0.2289
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9227 - loss: 0.2099 - val_accuracy: 0.9070 - val_loss: 0.2376
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9302, Precision: 0.7059, Recall: 0.7742, F1-Score: 0.7385
#
# === Fold 4/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 65s 6s/step - accuracy: 0.6553 - loss: 0.7473 - val_accuracy: 0.7209 - val_loss: 0.5484
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7364 - loss: 0.5929 - val_accuracy: 0.7209 - val_loss: 0.4918
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.7409 - loss: 0.5102 - val_accuracy: 0.6977 - val_loss: 0.4541
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7373 - loss: 0.4596 - val_accuracy: 0.7209 - val_loss: 0.4332
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7289 - loss: 0.4490 - val_accuracy: 0.7209 - val_loss: 0.4224
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8557 - loss: 0.3679 - val_accuracy: 0.7209 - val_loss: 0.4100
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7756 - loss: 0.4027 - val_accuracy: 0.7442 - val_loss: 0.3775
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8218 - loss: 0.3604 - val_accuracy: 0.7907 - val_loss: 0.3498
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8538 - loss: 0.3397 - val_accuracy: 0.7907 - val_loss: 0.3339
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8113 - loss: 0.3062 - val_accuracy: 0.8140 - val_loss: 0.3221
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8255 - loss: 0.3494 - val_accuracy: 0.8140 - val_loss: 0.3242
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8479 - loss: 0.3433 - val_accuracy: 0.8140 - val_loss: 0.3212
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8603 - loss: 0.3097 - val_accuracy: 0.8140 - val_loss: 0.3097
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8463 - loss: 0.2966 - val_accuracy: 0.8605 - val_loss: 0.2928
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.9335 - loss: 0.2238 - val_accuracy: 0.8372 - val_loss: 0.2961
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8716 - loss: 0.2802 - val_accuracy: 0.8605 - val_loss: 0.2834
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8636 - loss: 0.2924 - val_accuracy: 0.8837 - val_loss: 0.2748
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8875 - loss: 0.2696 - val_accuracy: 0.8837 - val_loss: 0.2698
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8431 - loss: 0.3010 - val_accuracy: 0.8605 - val_loss: 0.2775
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9231 - loss: 0.2237 - val_accuracy: 0.8605 - val_loss: 0.2741
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9089 - loss: 0.3280 - val_accuracy: 0.8837 - val_loss: 0.2569
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8772 - loss: 0.2562 - val_accuracy: 0.8837 - val_loss: 0.2496
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9005 - loss: 0.2293 - val_accuracy: 0.8837 - val_loss: 0.2498
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9188 - loss: 0.2333 - val_accuracy: 0.8605 - val_loss: 0.2562
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8473 - loss: 0.2989 - val_accuracy: 0.9302 - val_loss: 0.2317
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9302, Precision: 0.7059, Recall: 0.7742, F1-Score: 0.7385
#
# === Fold 5/5 ===
# Found 172 validated image filenames belonging to 2 classes.
# Found 42 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 66s 6s/step - accuracy: 0.4857 - loss: 0.8232 - val_accuracy: 0.7381 - val_loss: 0.5008
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7275 - loss: 0.6234 - val_accuracy: 0.7381 - val_loss: 0.4792
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.7265 - loss: 0.5650 - val_accuracy: 0.7619 - val_loss: 0.4284
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7773 - loss: 0.4559 - val_accuracy: 0.7857 - val_loss: 0.3967
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7948 - loss: 0.4065 - val_accuracy: 0.8333 - val_loss: 0.3760
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7489 - loss: 0.4884 - val_accuracy: 0.8333 - val_loss: 0.3621
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8199 - loss: 0.3775 - val_accuracy: 0.8571 - val_loss: 0.3460
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8461 - loss: 0.3483 - val_accuracy: 0.8571 - val_loss: 0.3370
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8338 - loss: 0.3571 - val_accuracy: 0.8571 - val_loss: 0.3229
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8663 - loss: 0.2894 - val_accuracy: 0.8571 - val_loss: 0.3147
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8572 - loss: 0.3057 - val_accuracy: 0.9048 - val_loss: 0.2986
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7943 - loss: 0.3905 - val_accuracy: 0.9048 - val_loss: 0.2822
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8899 - loss: 0.2970 - val_accuracy: 0.9048 - val_loss: 0.2749
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.9017 - loss: 0.3377 - val_accuracy: 0.9048 - val_loss: 0.2717
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9234 - loss: 0.1987 - val_accuracy: 0.9048 - val_loss: 0.2660
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.8820 - loss: 0.2603 - val_accuracy: 0.9048 - val_loss: 0.2566
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8495 - loss: 0.3126 - val_accuracy: 0.9048 - val_loss: 0.2454
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9119 - loss: 0.2487 - val_accuracy: 0.8810 - val_loss: 0.2381
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8963 - loss: 0.2735 - val_accuracy: 0.9048 - val_loss: 0.2358
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9358 - loss: 0.2316 - val_accuracy: 0.9048 - val_loss: 0.2310
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8632 - loss: 0.3157 - val_accuracy: 0.8810 - val_loss: 0.2228
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9032 - loss: 0.2353 - val_accuracy: 0.9048 - val_loss: 0.2283
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8803 - loss: 0.2902 - val_accuracy: 0.8810 - val_loss: 0.2187
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9155 - loss: 0.2525 - val_accuracy: 0.9048 - val_loss: 0.2134
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8945 - loss: 0.2514 - val_accuracy: 0.8810 - val_loss: 0.2134
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9048, Precision: 0.7879, Recall: 0.8387, F1-Score: 0.8125
#
# 5-Fold CV Metrics:
# Mean Accuracy: 0.9065
# Mean Precision: 0.7199
# Mean Recall: 0.7935
# Mean F1-Score: 0.7546
#
# Final Results:
# Accuracy = 0.9065, Precision = 0.7199, Recall = 0.7935, F1-Score = 0.7546
