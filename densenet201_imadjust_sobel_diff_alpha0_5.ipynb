# %% [markdown]
# <a href="https://colab.research.google.com/github/ffatmanurggultekin/scoliosis-detection/blob/main/densenet201_imadjust_sobel_diff_alpha0_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#############################################
# 1) Klasör Yolları ve Ayarlar
#############################################
train_dir = "/content/drive/MyDrive/train_imadjust_sobel_diff_alpha0.5"
val_dir = "/content/drive/MyDrive/validation_imadjust_sobel_diff_alpha0.5"

batch_size = 32
epochs = 50
n_splits = 5  # Cross-validation kat sayısı

# %%
#############################################
# 2) Veri Yollarını ve Etiketlerini Toplama
#############################################
def gather_paths_and_labels(dir_path):
    filepaths = []
    labels = []

    normal_path = os.path.join(dir_path, "Normal")
    scol_path = os.path.join(dir_path, "Scol")

    if os.path.exists(normal_path):
        for fname in os.listdir(normal_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(normal_path, fname))
                labels.append(0)  # Normal => 0

    if os.path.exists(scol_path):
        for fname in os.listdir(scol_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(scol_path, fname))
                labels.append(1)  # Scol => 1

    return pd.DataFrame({'filepath': filepaths, 'label': labels})

# Train ve Validation'dan gelen DataFrame'leri birleştirelim
df_train = gather_paths_and_labels(train_dir)
df_val = gather_paths_and_labels(val_dir)
df_trainVal = pd.concat([df_train, df_val], ignore_index=True)

# Label sütununu string formatına çevir
df_trainVal['label'] = df_trainVal['label'].astype(str)

print(f"Train+Validation birleşik boyutu: {len(df_trainVal)}")
# Out:
# Train+Validation birleşik boyutu: 0

# %%
#############################################
# 3) DenseNet201 Modelini Oluşturma
#############################################
def create_densenet201_model():
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers:
        layer.trainable = False  # Fine-tuning yapmayacaksanız dondurun

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=base_model.input, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
#############################################
# 4) Cross-Validation Fonksiyonu
#############################################
def run_5fold_cv(df, n_splits=5, epochs=50, batch_size=32):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    X = df['filepath'].values
    y = df['label'].values

    accuracy_list = []
    precision_list = []
    recall_list = []
    f1_list = []
    fold_no = 1

    # Data Augmentation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    val_datagen = ImageDataGenerator(rescale=1./255)

    for train_idx, val_idx in skf.split(X, y):
        print(f"\n=== Fold {fold_no}/{n_splits} ===")

        # Fold için Train/Validation veri setlerini ayır
        train_fold = df.iloc[train_idx]
        val_fold = df.iloc[val_idx]

        # Data generator'lar
        train_gen = train_datagen.flow_from_dataframe(
            train_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )
        val_gen = val_datagen.flow_from_dataframe(
            val_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )

        # Modeli oluştur
        model = create_densenet201_model()

        # EarlyStopping
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        steps_per_epoch = math.ceil(len(train_fold) / batch_size)
        validation_steps = math.ceil(len(val_fold) / batch_size)

        # Modeli eğit
        history = model.fit(
            train_gen,
            epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            validation_data=val_gen,
            validation_steps=validation_steps,
            callbacks=[early_stopping],
            verbose=1
        )

        # Validation setinde değerlendirme
        val_loss, val_acc = model.evaluate(val_gen, steps=validation_steps, verbose=0)
        accuracy_list.append(val_acc)

        # Confusion Matrix ve Classification Report
        y_val_pred_prob = model.predict(val_gen, steps=validation_steps, verbose=0)
        y_val_pred = (y_val_pred_prob > 0.5).astype(int).ravel()
        y_val_true = val_fold['label'].astype(int).values

        precision = precision_score(y_val_true, y_val_pred, average='binary')
        recall = recall_score(y_val_true, y_val_pred, average='binary')
        f1 = f1_score(y_val_true, y_val_pred, average='binary')

        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

        print("\nValidation Metrics:")
        print(f"Accuracy: {val_acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

        fold_no += 1

    mean_acc = np.mean(accuracy_list)
    mean_precision = np.mean(precision_list)
    mean_recall = np.mean(recall_list)
    mean_f1 = np.mean(f1_list)

    print("\n5-Fold CV Metrics:")
    print(f"Mean Accuracy: {mean_acc:.4f}")
    print(f"Mean Precision: {mean_precision:.4f}")
    print(f"Mean Recall: {mean_recall:.4f}")
    print(f"Mean F1-Score: {mean_f1:.4f}")

    return mean_acc, mean_precision, mean_recall, mean_f1

# %%
#############################################
# 5) 5-Fold Cross-Validation'ı Çalıştır
#############################################
mean_acc, mean_precision, mean_recall, mean_f1 = run_5fold_cv(df_trainVal, n_splits=n_splits, epochs=epochs, batch_size=batch_size)
print(f"\nFinal Results:\nAccuracy = {mean_acc:.4f}, Precision = {mean_precision:.4f}, Recall = {mean_recall:.4f}, F1-Score = {mean_f1:.4f}")
# Out:
# === Fold 1/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 95s 8s/step - accuracy: 0.7152 - loss: 0.5924 - val_accuracy: 0.7209 - val_loss: 0.5275
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.7180 - loss: 0.5845 - val_accuracy: 0.7209 - val_loss: 0.4781
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7298 - loss: 0.4553 - val_accuracy: 0.7209 - val_loss: 0.4418
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7970 - loss: 0.4606 - val_accuracy: 0.7209 - val_loss: 0.4258
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7496 - loss: 0.4916 - val_accuracy: 0.7209 - val_loss: 0.4127
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7790 - loss: 0.4163 - val_accuracy: 0.7674 - val_loss: 0.3876
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7743 - loss: 0.4366 - val_accuracy: 0.8140 - val_loss: 0.3536
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7921 - loss: 0.4021 - val_accuracy: 0.8605 - val_loss: 0.3343
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8558 - loss: 0.3412 - val_accuracy: 0.8372 - val_loss: 0.3276
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.8414 - loss: 0.3543 - val_accuracy: 0.8372 - val_loss: 0.3224
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.8017 - loss: 0.4059 - val_accuracy: 0.8605 - val_loss: 0.2973
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.8499 - loss: 0.3168 - val_accuracy: 0.9302 - val_loss: 0.2845
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.8664 - loss: 0.3190 - val_accuracy: 0.9535 - val_loss: 0.2709
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8606 - loss: 0.3279 - val_accuracy: 0.9535 - val_loss: 0.2631
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8246 - loss: 0.3831 - val_accuracy: 0.9535 - val_loss: 0.2480
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8793 - loss: 0.3170 - val_accuracy: 0.9535 - val_loss: 0.2368
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8943 - loss: 0.2553 - val_accuracy: 0.9535 - val_loss: 0.2268
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8977 - loss: 0.2913 - val_accuracy: 0.9535 - val_loss: 0.2228
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.9255 - loss: 0.2461 - val_accuracy: 0.9302 - val_loss: 0.2168
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8688 - loss: 0.2912 - val_accuracy: 0.9302 - val_loss: 0.2128
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9128 - loss: 0.2351 - val_accuracy: 0.9535 - val_loss: 0.1989
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8945 - loss: 0.2793 - val_accuracy: 0.9535 - val_loss: 0.1942
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9155 - loss: 0.2567 - val_accuracy: 0.9535 - val_loss: 0.1866
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.9324 - loss: 0.2389 - val_accuracy: 0.9535 - val_loss: 0.1808
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9099 - loss: 0.2489 - val_accuracy: 0.9535 - val_loss: 0.1745
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9535, Precision: 0.6970, Recall: 0.7419, F1-Score: 0.7188
#
# === Fold 2/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 6s/step - accuracy: 0.5469 - loss: 0.7477 - val_accuracy: 0.7209 - val_loss: 0.6014
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.6682 - loss: 0.6335 - val_accuracy: 0.7209 - val_loss: 0.5514
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7241 - loss: 0.5700 - val_accuracy: 0.7209 - val_loss: 0.5136
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7493 - loss: 0.4935 - val_accuracy: 0.7442 - val_loss: 0.4639
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8044 - loss: 0.4211 - val_accuracy: 0.7442 - val_loss: 0.4390
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8148 - loss: 0.4374 - val_accuracy: 0.7442 - val_loss: 0.4307
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.7249 - loss: 0.4908 - val_accuracy: 0.7442 - val_loss: 0.4032
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7223 - loss: 0.4782 - val_accuracy: 0.7674 - val_loss: 0.3699
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8046 - loss: 0.3591 - val_accuracy: 0.7674 - val_loss: 0.3696
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8043 - loss: 0.4192 - val_accuracy: 0.7674 - val_loss: 0.3733
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8687 - loss: 0.3195 - val_accuracy: 0.7674 - val_loss: 0.3460
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8663 - loss: 0.3306 - val_accuracy: 0.8140 - val_loss: 0.3136
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8544 - loss: 0.3315 - val_accuracy: 0.8140 - val_loss: 0.3027
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8255 - loss: 0.3443 - val_accuracy: 0.8140 - val_loss: 0.2980
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8474 - loss: 0.3068 - val_accuracy: 0.8140 - val_loss: 0.3022
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8638 - loss: 0.3021 - val_accuracy: 0.8372 - val_loss: 0.2760
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8594 - loss: 0.3683 - val_accuracy: 0.9070 - val_loss: 0.2508
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8945 - loss: 0.2841 - val_accuracy: 0.9070 - val_loss: 0.2421
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8944 - loss: 0.2687 - val_accuracy: 0.8837 - val_loss: 0.2423
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8923 - loss: 0.2908 - val_accuracy: 0.8837 - val_loss: 0.2479
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.9084 - loss: 0.2618 - val_accuracy: 0.9070 - val_loss: 0.2290
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8886 - loss: 0.2656 - val_accuracy: 0.9070 - val_loss: 0.2213
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.8978 - loss: 0.2671 - val_accuracy: 0.9070 - val_loss: 0.2167
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9071 - loss: 0.2571 - val_accuracy: 0.9070 - val_loss: 0.2044
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8756 - loss: 0.2882 - val_accuracy: 0.9302 - val_loss: 0.1854
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9302, Precision: 0.7059, Recall: 0.7742, F1-Score: 0.7385
#
# === Fold 3/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 70s 6s/step - accuracy: 0.4710 - loss: 0.9862 - val_accuracy: 0.7209 - val_loss: 0.5602
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.6827 - loss: 0.6318 - val_accuracy: 0.7209 - val_loss: 0.6298
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7507 - loss: 0.4768 - val_accuracy: 0.7209 - val_loss: 0.6024
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.7997 - loss: 0.4586 - val_accuracy: 0.7209 - val_loss: 0.5398
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.6841 - loss: 0.4955 - val_accuracy: 0.6977 - val_loss: 0.5123
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7801 - loss: 0.3766 - val_accuracy: 0.7209 - val_loss: 0.4945
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 164ms/step - accuracy: 0.7557 - loss: 0.5195 - val_accuracy: 0.7209 - val_loss: 0.4866
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7899 - loss: 0.4114 - val_accuracy: 0.7209 - val_loss: 0.4733
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8006 - loss: 0.4034 - val_accuracy: 0.7442 - val_loss: 0.4732
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8063 - loss: 0.4084 - val_accuracy: 0.7442 - val_loss: 0.4833
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8514 - loss: 0.3396 - val_accuracy: 0.7442 - val_loss: 0.4645
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8342 - loss: 0.3172 - val_accuracy: 0.7442 - val_loss: 0.4529
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8519 - loss: 0.3062 - val_accuracy: 0.7674 - val_loss: 0.4245
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8414 - loss: 0.3209 - val_accuracy: 0.7907 - val_loss: 0.4065
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8623 - loss: 0.3090 - val_accuracy: 0.8140 - val_loss: 0.3753
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8641 - loss: 0.3160 - val_accuracy: 0.8372 - val_loss: 0.3679
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8293 - loss: 0.3241 - val_accuracy: 0.8140 - val_loss: 0.3823
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8952 - loss: 0.2798 - val_accuracy: 0.8372 - val_loss: 0.3862
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8951 - loss: 0.2509 - val_accuracy: 0.8372 - val_loss: 0.3793
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.9154 - loss: 0.2548 - val_accuracy: 0.8372 - val_loss: 0.3387
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9204 - loss: 0.2555 - val_accuracy: 0.8837 - val_loss: 0.3129
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8713 - loss: 0.2919 - val_accuracy: 0.8837 - val_loss: 0.3048
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8827 - loss: 0.2730 - val_accuracy: 0.8837 - val_loss: 0.2974
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8951 - loss: 0.2369 - val_accuracy: 0.8837 - val_loss: 0.2922
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8772 - loss: 0.2611 - val_accuracy: 0.8837 - val_loss: 0.2822
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.8837, Precision: 0.8125, Recall: 0.8387, F1-Score: 0.8254
#
# === Fold 4/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 66s 6s/step - accuracy: 0.6621 - loss: 0.6545 - val_accuracy: 0.7209 - val_loss: 0.5183
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7579 - loss: 0.5356 - val_accuracy: 0.7209 - val_loss: 0.4711
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.6902 - loss: 0.5964 - val_accuracy: 0.7442 - val_loss: 0.4355
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8001 - loss: 0.4179 - val_accuracy: 0.7907 - val_loss: 0.4109
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7456 - loss: 0.4435 - val_accuracy: 0.7674 - val_loss: 0.4046
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7968 - loss: 0.4324 - val_accuracy: 0.7907 - val_loss: 0.3958
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8028 - loss: 0.4349 - val_accuracy: 0.8372 - val_loss: 0.3798
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.8474 - loss: 0.3884 - val_accuracy: 0.8372 - val_loss: 0.3438
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8677 - loss: 0.3416 - val_accuracy: 0.8605 - val_loss: 0.3299
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8457 - loss: 0.3358 - val_accuracy: 0.8372 - val_loss: 0.3275
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8948 - loss: 0.2790 - val_accuracy: 0.8605 - val_loss: 0.3098
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8695 - loss: 0.3203 - val_accuracy: 0.8605 - val_loss: 0.2946
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8593 - loss: 0.3365 - val_accuracy: 0.9070 - val_loss: 0.2815
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8832 - loss: 0.2729 - val_accuracy: 0.9302 - val_loss: 0.2646
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8636 - loss: 0.2899 - val_accuracy: 0.9535 - val_loss: 0.2518
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.9258 - loss: 0.2724 - val_accuracy: 0.9535 - val_loss: 0.2480
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8910 - loss: 0.2862 - val_accuracy: 0.9535 - val_loss: 0.2501
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8769 - loss: 0.2691 - val_accuracy: 0.9302 - val_loss: 0.2545
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9067 - loss: 0.2401 - val_accuracy: 0.9535 - val_loss: 0.2376
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9326 - loss: 0.2194 - val_accuracy: 0.9535 - val_loss: 0.2233
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9006 - loss: 0.2731 - val_accuracy: 0.9535 - val_loss: 0.2218
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9443 - loss: 0.2277 - val_accuracy: 0.9535 - val_loss: 0.2305
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8588 - loss: 0.2631 - val_accuracy: 0.9535 - val_loss: 0.2190
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8926 - loss: 0.2310 - val_accuracy: 0.9535 - val_loss: 0.2176
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.9203 - loss: 0.2364 - val_accuracy: 0.9535 - val_loss: 0.2203
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9535, Precision: 0.7273, Recall: 0.7742, F1-Score: 0.7500
#
# === Fold 5/5 ===
# Found 172 validated image filenames belonging to 2 classes.
# Found 42 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 69s 6s/step - accuracy: 0.6512 - loss: 0.6335 - val_accuracy: 0.7619 - val_loss: 0.4518
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.7325 - loss: 0.5549 - val_accuracy: 0.7619 - val_loss: 0.4238
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7810 - loss: 0.4960 - val_accuracy: 0.7857 - val_loss: 0.3989
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7103 - loss: 0.5198 - val_accuracy: 0.7857 - val_loss: 0.3766
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7431 - loss: 0.4440 - val_accuracy: 0.8095 - val_loss: 0.3592
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7650 - loss: 0.4507 - val_accuracy: 0.8333 - val_loss: 0.3435
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.7706 - loss: 0.4121 - val_accuracy: 0.8333 - val_loss: 0.3336
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8312 - loss: 0.3612 - val_accuracy: 0.8333 - val_loss: 0.3212
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8563 - loss: 0.3579 - val_accuracy: 0.8810 - val_loss: 0.3099
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8323 - loss: 0.3411 - val_accuracy: 0.8810 - val_loss: 0.3021
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8761 - loss: 0.3385 - val_accuracy: 0.9286 - val_loss: 0.2934
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8374 - loss: 0.3491 - val_accuracy: 0.9048 - val_loss: 0.2907
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8890 - loss: 0.3192 - val_accuracy: 0.8333 - val_loss: 0.2928
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8549 - loss: 0.3525 - val_accuracy: 0.8810 - val_loss: 0.2770
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8665 - loss: 0.3126 - val_accuracy: 0.9286 - val_loss: 0.2590
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8438 - loss: 0.3403 - val_accuracy: 0.9524 - val_loss: 0.2478
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.9130 - loss: 0.2783 - val_accuracy: 0.9524 - val_loss: 0.2448
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8969 - loss: 0.2821 - val_accuracy: 0.9286 - val_loss: 0.2450
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.9092 - loss: 0.2599 - val_accuracy: 0.9286 - val_loss: 0.2404
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8613 - loss: 0.2689 - val_accuracy: 0.9286 - val_loss: 0.2271
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8849 - loss: 0.2925 - val_accuracy: 0.9524 - val_loss: 0.2173
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8789 - loss: 0.2819 - val_accuracy: 0.9524 - val_loss: 0.2145
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8783 - loss: 0.2303 - val_accuracy: 0.9286 - val_loss: 0.2160
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.8547 - loss: 0.3014 - val_accuracy: 0.9524 - val_loss: 0.2035
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.9083 - loss: 0.2349 - val_accuracy: 0.9524 - val_loss: 0.1952
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9524, Precision: 0.7879, Recall: 0.8387, F1-Score: 0.8125
#
# 5-Fold CV Metrics:
# Mean Accuracy: 0.9347
# Mean Precision: 0.7461
# Mean Recall: 0.7935
# Mean F1-Score: 0.7690
#
# Final Results:
# Accuracy = 0.9347, Precision = 0.7461, Recall = 0.7935, F1-Score = 0.7690
