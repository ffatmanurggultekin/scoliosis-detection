# %% [markdown]
# <a href="https://colab.research.google.com/github/ffatmanurggultekin/scoliosis-detection/blob/main/densenet201_imadjust%2Bclahe_mask_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os
import time  # Zaman ölçümü için
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from google.colab import drive

# ✅ Google Drive'ı bağla
drive.mount('/content/drive')

# ✅ Veri yolları
train_dir = '/content/drive/MyDrive/imadjust_clahe/train'
test_dir = '/content/drive/MyDrive/imadjust_clahe/test'

# ✅ Veri toplama fonksiyonu
def gather_paths_and_labels(directory):
    data = []
    for label, class_name in enumerate(['Normal', 'Scol']):
        class_dir = os.path.join(directory, class_name)
        for file in os.listdir(class_dir):
            data.append((os.path.join(class_dir, file), label))
    return np.array(data)

# ✅ Verileri yükleme
train_data = gather_paths_and_labels(train_dir)
test_data = gather_paths_and_labels(test_dir)

# ✅ Class Weights
class_weights_dict = {0: 1.0, 1: 0.7}
print(f"\nUpdated Class Weights: {class_weights_dict}")

# ✅ Veri artırma (Data Augmentation)
train_datagen = ImageDataGenerator(
    rescale=1./255, rotation_range=15, width_shift_range=0.2,
    height_shift_range=0.2, zoom_range=[0.8, 1.2], horizontal_flip=True
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# ✅ DenseNet201 Modeli
def create_densenet201_model():
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    for layer in base_model.layers[:-10]:  # Son 10 katman dışında tümünü dondur
        layer.trainable = False
    for layer in base_model.layers[-10:]:
        layer.trainable = True

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=base_model.input, outputs=output)
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])
    return model

# ✅ Cross-Validation Süresi ve Train Accuracy Ölçümü
def run_cross_validation(data, n_splits=5, epochs=50, batch_size=32):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    accuracy_list, fold_times = [], []

    total_start_time = time.time()  # ⏳ Cross-validation süresini başlat

    for fold, (train_idx, val_idx) in enumerate(skf.split(data[:, 0], data[:, 1])):
        print(f"\n=== Fold {fold + 1}/{n_splits} ===")

        fold_start_time = time.time()

        train_files, val_files = data[train_idx], data[val_idx]
        train_df = pd.DataFrame({'filename': train_files[:, 0], 'class': train_files[:, 1]})
        val_df = pd.DataFrame({'filename': val_files[:, 0], 'class': val_files[:, 1]})

        train_gen = train_datagen.flow_from_dataframe(
            train_df, x_col='filename', y_col='class',
            target_size=(224, 224), batch_size=batch_size, class_mode='binary', shuffle=True
        )

        val_gen = val_test_datagen.flow_from_dataframe(
            val_df, x_col='filename', y_col='class',
            target_size=(224, 224), batch_size=batch_size, class_mode='binary', shuffle=False
        )

        model = create_densenet201_model()
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        model.fit(train_gen, validation_data=val_gen, epochs=epochs, callbacks=[early_stopping], class_weight=class_weights_dict, verbose=1)

        fold_end_time = time.time()
        fold_time = fold_end_time - fold_start_time
        fold_times.append(fold_time)

        print(f"Fold {fold + 1} eğitim süresi: {fold_time:.2f} saniye")

        val_labels = val_files[:, 1].astype(int)
        val_probs = model.predict(val_gen).ravel()
        val_preds = (val_probs > 0.5).astype(int)
        accuracy = accuracy_score(val_labels, val_preds)

        accuracy_list.append(accuracy)

    total_end_time = time.time()
    total_cv_time = total_end_time - total_start_time

    mean_train_acc = np.mean(accuracy_list)
    std_train_acc = np.std(accuracy_list)

    print(f"\n⏳ Toplam Cross-Validation Süresi: {total_cv_time:.2f} saniye")
    print(f"Train Accuracy: {mean_train_acc:.4f} ± {std_train_acc:.4f}")

    return total_cv_time, mean_train_acc, std_train_acc

# ✅ Final Model Eğitimi ve Test Değerlendirme
def evaluate_final_model(model, test_data):
    test_df = pd.DataFrame({'filename': test_data[:, 0], 'class': test_data[:, 1]})
    test_gen = val_test_datagen.flow_from_dataframe(
        test_df, x_col='filename', y_col='class',
        target_size=(224, 224), batch_size=32, class_mode='binary', shuffle=False
    )

    test_labels = test_data[:, 1].astype(int)
    test_probs = model.predict(test_gen).ravel()
    test_preds = (test_probs > 0.5).astype(int)

    test_accuracy = accuracy_score(test_labels, test_preds)
    test_f1 = f1_score(test_labels, test_preds)

    cm = confusion_matrix(test_labels, test_preds)

    print("\n=== Final Model Test Sonuçları ===")
    print(f"Test Accuracy: {test_accuracy:.4f}")
    print(f"Test F1 Score: {test_f1:.4f}")

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Normal", "Scol"], yticklabels=["Normal", "Scol"])
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix - Final Model")
    plt.show()

    return test_accuracy, test_f1

# ✅ Model Eğitimi
cv_time, mean_train_acc, std_train_acc = run_cross_validation(train_data, n_splits=5, epochs=50, batch_size=32)
final_model = create_densenet201_model()
final_model.fit(train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='binary'), epochs=50)
test_acc, test_f1 = evaluate_final_model(final_model, test_data)

# ✅ Sonuçları Yazdır
print("\n=== Sonuçlar ===")
print(f"Toplam Hesaplama Süresi: {cv_time:.2f} saniye")
print(f"Train Accuracy: {mean_train_acc:.4f} ± {std_train_acc:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test F1 Score: {test_f1:.4f}")
# Out:
# Mounted at /content/drive
#
# Updated Class Weights: {0: 1.0, 1: 0.7}
#
# === Fold 1/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.4365 - loss: 0.6514 - val_accuracy: 0.7500 - val_loss: 0.6104
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6807 - loss: 0.6323 - val_accuracy: 0.7500 - val_loss: 0.5219
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7599 - loss: 0.4895 - val_accuracy: 0.7778 - val_loss: 0.4909
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7724 - loss: 0.4220 - val_accuracy: 0.8333 - val_loss: 0.4724
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7263 - loss: 0.4212 - val_accuracy: 0.8333 - val_loss: 0.4421
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7932 - loss: 0.3795 - val_accuracy: 0.8611 - val_loss: 0.4156
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7975 - loss: 0.3525 - val_accuracy: 0.8611 - val_loss: 0.3879
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8313 - loss: 0.2871 - val_accuracy: 0.8611 - val_loss: 0.3608
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8233 - loss: 0.3008 - val_accuracy: 0.8611 - val_loss: 0.3435
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8929 - loss: 0.2546 - val_accuracy: 0.8611 - val_loss: 0.3298
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 998ms/step - accuracy: 0.8909 - loss: 0.2508 - val_accuracy: 0.8611 - val_loss: 0.3168
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 999ms/step - accuracy: 0.8790 - loss: 0.2338 - val_accuracy: 0.8889 - val_loss: 0.3052
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8933 - loss: 0.2081 - val_accuracy: 0.9167 - val_loss: 0.2956
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8866 - loss: 0.2249 - val_accuracy: 0.9167 - val_loss: 0.2824
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 977ms/step - accuracy: 0.9366 - loss: 0.1794 - val_accuracy: 0.8889 - val_loss: 0.2723
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9284 - loss: 0.1536 - val_accuracy: 0.9167 - val_loss: 0.2638
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9278 - loss: 0.1482 - val_accuracy: 0.8889 - val_loss: 0.2589
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9252 - loss: 0.1997 - val_accuracy: 0.9167 - val_loss: 0.2457
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8953 - loss: 0.1730 - val_accuracy: 0.9167 - val_loss: 0.2367
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9665 - loss: 0.1252 - val_accuracy: 0.9167 - val_loss: 0.2264
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9125 - loss: 0.1885 - val_accuracy: 0.9444 - val_loss: 0.2131
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9168 - loss: 0.1686 - val_accuracy: 0.9444 - val_loss: 0.2024
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9443 - loss: 0.1162 - val_accuracy: 0.9444 - val_loss: 0.1955
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9127 - loss: 0.1921 - val_accuracy: 0.9444 - val_loss: 0.1899
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9877 - loss: 0.0722 - val_accuracy: 0.9444 - val_loss: 0.1866
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9592 - loss: 0.0872 - val_accuracy: 0.9444 - val_loss: 0.1842
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9549 - loss: 0.1001 - val_accuracy: 0.9444 - val_loss: 0.1815
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9810 - loss: 0.0710 - val_accuracy: 0.9444 - val_loss: 0.1794
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9848 - loss: 0.0703 - val_accuracy: 0.9444 - val_loss: 0.1761
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9905 - loss: 0.0579 - val_accuracy: 0.9444 - val_loss: 0.1733
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9311 - loss: 0.1165 - val_accuracy: 0.9444 - val_loss: 0.1594
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9727 - loss: 0.0810 - val_accuracy: 0.9444 - val_loss: 0.1550
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9719 - loss: 0.0763 - val_accuracy: 0.9444 - val_loss: 0.1520
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9748 - loss: 0.0743 - val_accuracy: 0.9444 - val_loss: 0.1519
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9889 - loss: 0.0386 - val_accuracy: 0.9444 - val_loss: 0.1532
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 1.0000 - loss: 0.0403 - val_accuracy: 0.9444 - val_loss: 0.1529
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 999ms/step - accuracy: 0.9946 - loss: 0.0321 - val_accuracy: 0.9444 - val_loss: 0.1520
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9787 - loss: 0.0651 - val_accuracy: 0.9444 - val_loss: 0.1527
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 0.9444 - val_loss: 0.1542
# Fold 1 eğitim süresi: 244.94 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step
#
# === Fold 2/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.6581 - loss: 0.5267 - val_accuracy: 0.7222 - val_loss: 0.5411
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 980ms/step - accuracy: 0.7060 - loss: 0.5310 - val_accuracy: 0.7222 - val_loss: 0.4891
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8523 - loss: 0.3680 - val_accuracy: 0.7222 - val_loss: 0.4553
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 998ms/step - accuracy: 0.7677 - loss: 0.4116 - val_accuracy: 0.7778 - val_loss: 0.4192
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8059 - loss: 0.3725 - val_accuracy: 0.7778 - val_loss: 0.3880
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 994ms/step - accuracy: 0.7538 - loss: 0.3625 - val_accuracy: 0.8333 - val_loss: 0.3574
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8625 - loss: 0.3091 - val_accuracy: 0.8333 - val_loss: 0.3302
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8663 - loss: 0.3061 - val_accuracy: 0.8333 - val_loss: 0.3119
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 957ms/step - accuracy: 0.8848 - loss: 0.2588 - val_accuracy: 0.8056 - val_loss: 0.2961
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8562 - loss: 0.2663 - val_accuracy: 0.8611 - val_loss: 0.2699
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8558 - loss: 0.2513 - val_accuracy: 0.8611 - val_loss: 0.2571
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8498 - loss: 0.2576 - val_accuracy: 0.8611 - val_loss: 0.2507
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8950 - loss: 0.2119 - val_accuracy: 0.8611 - val_loss: 0.2424
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8876 - loss: 0.2418 - val_accuracy: 0.8611 - val_loss: 0.2099
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 998ms/step - accuracy: 0.9285 - loss: 0.1613 - val_accuracy: 0.8611 - val_loss: 0.1999
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9009 - loss: 0.1760 - val_accuracy: 0.9167 - val_loss: 0.1873
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9505 - loss: 0.1494 - val_accuracy: 0.8889 - val_loss: 0.1899
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 979ms/step - accuracy: 0.9469 - loss: 0.1391 - val_accuracy: 0.8889 - val_loss: 0.1912
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 999ms/step - accuracy: 0.9171 - loss: 0.1442 - val_accuracy: 0.9167 - val_loss: 0.1586
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9502 - loss: 0.1482 - val_accuracy: 0.9167 - val_loss: 0.1423
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 994ms/step - accuracy: 0.9290 - loss: 0.1433 - val_accuracy: 0.9167 - val_loss: 0.1512
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 988ms/step - accuracy: 0.9093 - loss: 0.1315 - val_accuracy: 0.9167 - val_loss: 0.1452
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9647 - loss: 0.1102 - val_accuracy: 0.9722 - val_loss: 0.1244
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9750 - loss: 0.1036 - val_accuracy: 0.9722 - val_loss: 0.1154
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 951ms/step - accuracy: 0.9892 - loss: 0.0859 - val_accuracy: 0.9722 - val_loss: 0.1179
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 976ms/step - accuracy: 0.9831 - loss: 0.0786 - val_accuracy: 0.9167 - val_loss: 0.1223
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9650 - loss: 0.1288 - val_accuracy: 0.9167 - val_loss: 0.1273
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9782 - loss: 0.0922 - val_accuracy: 0.9167 - val_loss: 0.1261
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9664 - loss: 0.1036 - val_accuracy: 0.9167 - val_loss: 0.1185
# Fold 2 eğitim süresi: 169.59 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step
#
# === Fold 3/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.3649 - loss: 0.6929 - val_accuracy: 0.6944 - val_loss: 0.6052
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6945 - loss: 0.5308 - val_accuracy: 0.7222 - val_loss: 0.5050
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 967ms/step - accuracy: 0.7141 - loss: 0.5203 - val_accuracy: 0.7500 - val_loss: 0.4516
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7635 - loss: 0.4038 - val_accuracy: 0.8333 - val_loss: 0.4175
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7716 - loss: 0.3672 - val_accuracy: 0.9167 - val_loss: 0.3904
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 999ms/step - accuracy: 0.8393 - loss: 0.3262 - val_accuracy: 0.9444 - val_loss: 0.3551
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7886 - loss: 0.3671 - val_accuracy: 0.9167 - val_loss: 0.3191
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8197 - loss: 0.3583 - val_accuracy: 0.8889 - val_loss: 0.2957
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8863 - loss: 0.2553 - val_accuracy: 0.8889 - val_loss: 0.2789
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8078 - loss: 0.3309 - val_accuracy: 0.9167 - val_loss: 0.2644
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8724 - loss: 0.2859 - val_accuracy: 0.9444 - val_loss: 0.2461
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8849 - loss: 0.2437 - val_accuracy: 0.9722 - val_loss: 0.2281
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8623 - loss: 0.2846 - val_accuracy: 0.9722 - val_loss: 0.2119
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9064 - loss: 0.2231 - val_accuracy: 0.9722 - val_loss: 0.1960
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9063 - loss: 0.2139 - val_accuracy: 0.9722 - val_loss: 0.1801
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9174 - loss: 0.1836 - val_accuracy: 0.9722 - val_loss: 0.1750
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9640 - loss: 0.1427 - val_accuracy: 0.9722 - val_loss: 0.1710
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9517 - loss: 0.1768 - val_accuracy: 0.9722 - val_loss: 0.1542
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 987ms/step - accuracy: 0.9400 - loss: 0.1672 - val_accuracy: 1.0000 - val_loss: 0.1368
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9114 - loss: 0.1830 - val_accuracy: 1.0000 - val_loss: 0.1211
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9681 - loss: 0.1134 - val_accuracy: 1.0000 - val_loss: 0.1119
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9556 - loss: 0.1277 - val_accuracy: 1.0000 - val_loss: 0.1063
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 985ms/step - accuracy: 0.9535 - loss: 0.1292 - val_accuracy: 1.0000 - val_loss: 0.0926
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9547 - loss: 0.1255 - val_accuracy: 1.0000 - val_loss: 0.0822
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9696 - loss: 0.1043 - val_accuracy: 1.0000 - val_loss: 0.0772
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9696 - loss: 0.1145 - val_accuracy: 1.0000 - val_loss: 0.0724
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9685 - loss: 0.0989 - val_accuracy: 1.0000 - val_loss: 0.0683
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9707 - loss: 0.0929 - val_accuracy: 1.0000 - val_loss: 0.0594
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9719 - loss: 0.0881 - val_accuracy: 1.0000 - val_loss: 0.0540
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9767 - loss: 0.0831 - val_accuracy: 1.0000 - val_loss: 0.0517
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9623 - loss: 0.0802 - val_accuracy: 1.0000 - val_loss: 0.0498
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9751 - loss: 0.0810 - val_accuracy: 1.0000 - val_loss: 0.0517
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9828 - loss: 0.0627 - val_accuracy: 1.0000 - val_loss: 0.0494
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9757 - loss: 0.0767 - val_accuracy: 1.0000 - val_loss: 0.0416
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9644 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0357
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9860 - loss: 0.0554 - val_accuracy: 1.0000 - val_loss: 0.0336
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9868 - loss: 0.0562 - val_accuracy: 1.0000 - val_loss: 0.0304
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9789 - loss: 0.0727 - val_accuracy: 1.0000 - val_loss: 0.0294
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9977 - loss: 0.0458 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9945 - loss: 0.0370 - val_accuracy: 1.0000 - val_loss: 0.0274
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9883 - loss: 0.0530 - val_accuracy: 1.0000 - val_loss: 0.0260
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9941 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0255
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 1.0000 - loss: 0.0398 - val_accuracy: 1.0000 - val_loss: 0.0253
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 994ms/step - accuracy: 1.0000 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0249
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9811 - loss: 0.0410 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9939 - loss: 0.0262 - val_accuracy: 1.0000 - val_loss: 0.0233
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9915 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 998ms/step - accuracy: 1.0000 - loss: 0.0410 - val_accuracy: 1.0000 - val_loss: 0.0211
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9962 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9919 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0189
# Fold 3 eğitim süresi: 280.78 saniye
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e53043189a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 4s 5s/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e53043189a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step
#
# === Fold 4/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.4213 - loss: 0.6895 - val_accuracy: 0.7778 - val_loss: 0.6017
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7649 - loss: 0.4675 - val_accuracy: 0.7778 - val_loss: 0.5264
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7367 - loss: 0.4347 - val_accuracy: 0.7778 - val_loss: 0.4894
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7609 - loss: 0.4066 - val_accuracy: 0.7778 - val_loss: 0.4540
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7928 - loss: 0.3868 - val_accuracy: 0.8333 - val_loss: 0.4207
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7384 - loss: 0.3829 - val_accuracy: 0.8333 - val_loss: 0.3955
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7688 - loss: 0.3653 - val_accuracy: 0.8333 - val_loss: 0.3762
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8837 - loss: 0.2644 - val_accuracy: 0.8333 - val_loss: 0.3569
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8543 - loss: 0.2903 - val_accuracy: 0.8611 - val_loss: 0.3375
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 997ms/step - accuracy: 0.8896 - loss: 0.2227 - val_accuracy: 0.8611 - val_loss: 0.3200
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9084 - loss: 0.2202 - val_accuracy: 0.8611 - val_loss: 0.3031
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9052 - loss: 0.2365 - val_accuracy: 0.8889 - val_loss: 0.2808
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8750 - loss: 0.2100 - val_accuracy: 0.9167 - val_loss: 0.2477
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8825 - loss: 0.1912 - val_accuracy: 0.9167 - val_loss: 0.2304
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9624 - loss: 0.1415 - val_accuracy: 0.9167 - val_loss: 0.2226
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8720 - loss: 0.2206 - val_accuracy: 0.9167 - val_loss: 0.1942
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9470 - loss: 0.1405 - val_accuracy: 0.9167 - val_loss: 0.1787
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8859 - loss: 0.2134 - val_accuracy: 0.9722 - val_loss: 0.1614
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9433 - loss: 0.1428 - val_accuracy: 0.9444 - val_loss: 0.1587
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9622 - loss: 0.1273 - val_accuracy: 0.9444 - val_loss: 0.1597
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9655 - loss: 0.1232 - val_accuracy: 0.9444 - val_loss: 0.1478
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9737 - loss: 0.1099 - val_accuracy: 0.9722 - val_loss: 0.1372
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9672 - loss: 0.0938 - val_accuracy: 0.9722 - val_loss: 0.1263
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9939 - loss: 0.0689 - val_accuracy: 0.9722 - val_loss: 0.1179
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9816 - loss: 0.0867 - val_accuracy: 0.9722 - val_loss: 0.1127
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9249 - loss: 0.1370 - val_accuracy: 0.9722 - val_loss: 0.1031
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9502 - loss: 0.1031 - val_accuracy: 0.9722 - val_loss: 0.1045
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 984ms/step - accuracy: 0.9854 - loss: 0.0518 - val_accuracy: 0.9722 - val_loss: 0.1137
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9497 - loss: 0.1153 - val_accuracy: 0.9444 - val_loss: 0.1221
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9810 - loss: 0.0715 - val_accuracy: 0.9444 - val_loss: 0.1304
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 995ms/step - accuracy: 0.9880 - loss: 0.0473 - val_accuracy: 0.9444 - val_loss: 0.1236
# Fold 4 eğitim süresi: 182.12 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step
#
# === Fold 5/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.6179 - loss: 0.5729 - val_accuracy: 0.7500 - val_loss: 0.4866
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6765 - loss: 0.5364 - val_accuracy: 0.7222 - val_loss: 0.4461
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7643 - loss: 0.4134 - val_accuracy: 0.8333 - val_loss: 0.4127
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7582 - loss: 0.3746 - val_accuracy: 0.8333 - val_loss: 0.3818
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 996ms/step - accuracy: 0.7613 - loss: 0.3716 - val_accuracy: 0.8611 - val_loss: 0.3563
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8770 - loss: 0.2683 - val_accuracy: 0.8056 - val_loss: 0.3395
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8023 - loss: 0.3251 - val_accuracy: 0.8611 - val_loss: 0.3160
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8443 - loss: 0.3087 - val_accuracy: 0.8889 - val_loss: 0.2928
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 990ms/step - accuracy: 0.8559 - loss: 0.2545 - val_accuracy: 0.8889 - val_loss: 0.2756
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9131 - loss: 0.2262 - val_accuracy: 0.8889 - val_loss: 0.2580
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8805 - loss: 0.2201 - val_accuracy: 0.9167 - val_loss: 0.2399
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8827 - loss: 0.2190 - val_accuracy: 0.9167 - val_loss: 0.2307
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9197 - loss: 0.1859 - val_accuracy: 0.9444 - val_loss: 0.2163
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9206 - loss: 0.1918 - val_accuracy: 1.0000 - val_loss: 0.1970
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8942 - loss: 0.1756 - val_accuracy: 1.0000 - val_loss: 0.1821
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9302 - loss: 0.1459 - val_accuracy: 1.0000 - val_loss: 0.1717
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9504 - loss: 0.1295 - val_accuracy: 1.0000 - val_loss: 0.1598
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9394 - loss: 0.1390 - val_accuracy: 1.0000 - val_loss: 0.1469
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9556 - loss: 0.1302 - val_accuracy: 1.0000 - val_loss: 0.1354
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9284 - loss: 0.1332 - val_accuracy: 1.0000 - val_loss: 0.1197
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9314 - loss: 0.1116 - val_accuracy: 1.0000 - val_loss: 0.1080
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9892 - loss: 0.0809 - val_accuracy: 1.0000 - val_loss: 0.0983
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9414 - loss: 0.1366 - val_accuracy: 1.0000 - val_loss: 0.0907
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9867 - loss: 0.0676 - val_accuracy: 1.0000 - val_loss: 0.0829
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 999ms/step - accuracy: 0.9552 - loss: 0.0830 - val_accuracy: 1.0000 - val_loss: 0.0769
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9397 - loss: 0.1182 - val_accuracy: 1.0000 - val_loss: 0.0711
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9651 - loss: 0.0735 - val_accuracy: 1.0000 - val_loss: 0.0672
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9685 - loss: 0.0752 - val_accuracy: 1.0000 - val_loss: 0.0635
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9892 - loss: 0.0691 - val_accuracy: 1.0000 - val_loss: 0.0600
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9907 - loss: 0.0561 - val_accuracy: 1.0000 - val_loss: 0.0568
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9665 - loss: 0.0957 - val_accuracy: 1.0000 - val_loss: 0.0582
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9877 - loss: 0.0623 - val_accuracy: 1.0000 - val_loss: 0.0526
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9802 - loss: 0.0618 - val_accuracy: 1.0000 - val_loss: 0.0464
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 995ms/step - accuracy: 0.9719 - loss: 0.0605 - val_accuracy: 1.0000 - val_loss: 0.0419
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9795 - loss: 0.0612 - val_accuracy: 1.0000 - val_loss: 0.0390
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9656 - loss: 0.0608 - val_accuracy: 1.0000 - val_loss: 0.0408
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0424
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 999ms/step - accuracy: 0.9854 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0404
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9906 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0393
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9945 - loss: 0.0415 - val_accuracy: 1.0000 - val_loss: 0.0384
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 972ms/step - accuracy: 0.9910 - loss: 0.0309 - val_accuracy: 1.0000 - val_loss: 0.0372
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9915 - loss: 0.0487 - val_accuracy: 1.0000 - val_loss: 0.0397
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 997ms/step - accuracy: 0.9895 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0406
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 1.0000 - val_loss: 0.0403
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0387
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.9977 - loss: 0.0227 - val_accuracy: 1.0000 - val_loss: 0.0374
# Fold 5 eğitim süresi: 260.47 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 3s/step
#
# ⏳ Toplam Cross-Validation Süresi: 1176.42 saniye
# Train Accuracy: 0.9778 ± 0.0208
# Found 180 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 789ms/step - accuracy: 0.3854 - loss: 1.0188
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 811ms/step - accuracy: 0.7123 - loss: 0.6247
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 778ms/step - accuracy: 0.6795 - loss: 0.6588
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 774ms/step - accuracy: 0.7365 - loss: 0.5301
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 832ms/step - accuracy: 0.7802 - loss: 0.4198
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 809ms/step - accuracy: 0.8208 - loss: 0.4264
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 777ms/step - accuracy: 0.8951 - loss: 0.3398
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 749ms/step - accuracy: 0.8657 - loss: 0.3425
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 819ms/step - accuracy: 0.8216 - loss: 0.3408
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 748ms/step - accuracy: 0.8799 - loss: 0.2963
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 756ms/step - accuracy: 0.9072 - loss: 0.2607
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 793ms/step - accuracy: 0.8988 - loss: 0.2629
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 834ms/step - accuracy: 0.9026 - loss: 0.2503
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 802ms/step - accuracy: 0.9378 - loss: 0.2130
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 788ms/step - accuracy: 0.9270 - loss: 0.1965
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 784ms/step - accuracy: 0.9699 - loss: 0.1580
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 769ms/step - accuracy: 0.9613 - loss: 0.1592
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 785ms/step - accuracy: 0.9552 - loss: 0.1504
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 792ms/step - accuracy: 0.9307 - loss: 0.1801
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 758ms/step - accuracy: 0.9767 - loss: 0.1248
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 784ms/step - accuracy: 0.9299 - loss: 0.1481
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 752ms/step - accuracy: 0.9670 - loss: 0.0951
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 836ms/step - accuracy: 0.9447 - loss: 0.1637
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 761ms/step - accuracy: 0.9853 - loss: 0.0800
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 758ms/step - accuracy: 0.9704 - loss: 0.1226
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 760ms/step - accuracy: 0.9501 - loss: 0.1206
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 820ms/step - accuracy: 0.9894 - loss: 0.0896
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 783ms/step - accuracy: 0.9866 - loss: 0.0683
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 830ms/step - accuracy: 0.9959 - loss: 0.0602
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 784ms/step - accuracy: 0.9591 - loss: 0.1232
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 761ms/step - accuracy: 0.9962 - loss: 0.0439
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 794ms/step - accuracy: 0.9818 - loss: 0.0903
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 797ms/step - accuracy: 0.9896 - loss: 0.0578
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 795ms/step - accuracy: 0.9813 - loss: 0.0647
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 794ms/step - accuracy: 0.9974 - loss: 0.0420
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 796ms/step - accuracy: 0.9923 - loss: 0.0594
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 822ms/step - accuracy: 0.9827 - loss: 0.0730
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 791ms/step - accuracy: 0.9803 - loss: 0.0433
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 788ms/step - accuracy: 0.9920 - loss: 0.0396
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 784ms/step - accuracy: 0.9857 - loss: 0.0529
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 806ms/step - accuracy: 0.9897 - loss: 0.0413
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 792ms/step - accuracy: 0.9950 - loss: 0.0240
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 769ms/step - accuracy: 0.9949 - loss: 0.0309
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 783ms/step - accuracy: 0.9846 - loss: 0.0271
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 772ms/step - accuracy: 1.0000 - loss: 0.0315
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 824ms/step - accuracy: 0.9880 - loss: 0.0406
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 780ms/step - accuracy: 0.9881 - loss: 0.0417
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 761ms/step - accuracy: 0.9925 - loss: 0.0319
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 775ms/step - accuracy: 0.9975 - loss: 0.0229
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 749ms/step - accuracy: 0.9984 - loss: 0.0181
# Found 79 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 14s 5s/step
#
# === Final Model Test Sonuçları ===
# Test Accuracy: 0.9873
# Test F1 Score: 0.9913
# === Sonuçlar ===
# Toplam Hesaplama Süresi: 1176.42 saniye
# Train Accuracy: 0.9778 ± 0.0208
# Test Accuracy: 0.9873
# Test F1 Score: 0.9913
