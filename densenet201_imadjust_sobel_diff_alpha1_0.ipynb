# %% [markdown]
# <a href="https://colab.research.google.com/github/ffatmanurggultekin/scoliosis-detection/blob/main/densenet201_imadjust_sobel_diff_alpha1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#############################################
# 1) Klasör Yolları ve Ayarlar
#############################################
train_dir = "/content/drive/MyDrive/train_imadjust_sobel_diff_alpha1.0"
val_dir = "/content/drive/MyDrive/validation_imadjust_sobel_diff_alpha1.0"

batch_size = 32
epochs = 50
n_splits = 5  # Cross-validation kat sayısı

# %%
#############################################
# 2) Veri Yollarını ve Etiketlerini Toplama
#############################################
def gather_paths_and_labels(dir_path):
    filepaths = []
    labels = []

    normal_path = os.path.join(dir_path, "Normal")
    scol_path = os.path.join(dir_path, "Scol")

    if os.path.exists(normal_path):
        for fname in os.listdir(normal_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(normal_path, fname))
                labels.append(0)  # Normal => 0

    if os.path.exists(scol_path):
        for fname in os.listdir(scol_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(scol_path, fname))
                labels.append(1)  # Scol => 1

    return pd.DataFrame({'filepath': filepaths, 'label': labels})

# Train ve Validation'dan gelen DataFrame'leri birleştirelim
df_train = gather_paths_and_labels(train_dir)
df_val = gather_paths_and_labels(val_dir)
df_trainVal = pd.concat([df_train, df_val], ignore_index=True)

# Label sütununu string formatına çevir
df_trainVal['label'] = df_trainVal['label'].astype(str)

print(f"Train+Validation birleşik boyutu: {len(df_trainVal)}")
# Out:
# Train+Validation birleşik boyutu: 214

# %%
#############################################
# 3) DenseNet201 Modelini Oluşturma
#############################################
def create_densenet201_model():
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers:
        layer.trainable = False  # Fine-tuning yapmayacaksanız dondurun

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=base_model.input, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
#############################################
# 4) Cross-Validation Fonksiyonu
#############################################
def run_5fold_cv(df, n_splits=5, epochs=50, batch_size=32):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    X = df['filepath'].values
    y = df['label'].values

    accuracy_list = []
    precision_list = []
    recall_list = []
    f1_list = []
    fold_no = 1

    # Data Augmentation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    val_datagen = ImageDataGenerator(rescale=1./255)

    for train_idx, val_idx in skf.split(X, y):
        print(f"\n=== Fold {fold_no}/{n_splits} ===")

        # Fold için Train/Validation veri setlerini ayır
        train_fold = df.iloc[train_idx]
        val_fold = df.iloc[val_idx]

        # Data generator'lar
        train_gen = train_datagen.flow_from_dataframe(
            train_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )
        val_gen = val_datagen.flow_from_dataframe(
            val_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )

        # Modeli oluştur
        model = create_densenet201_model()

        # EarlyStopping
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        steps_per_epoch = math.ceil(len(train_fold) / batch_size)
        validation_steps = math.ceil(len(val_fold) / batch_size)

        # Modeli eğit
        history = model.fit(
            train_gen,
            epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            validation_data=val_gen,
            validation_steps=validation_steps,
            callbacks=[early_stopping],
            verbose=1
        )

        # Validation setinde değerlendirme
        val_loss, val_acc = model.evaluate(val_gen, steps=validation_steps, verbose=0)
        accuracy_list.append(val_acc)

        # Confusion Matrix ve Classification Report
        y_val_pred_prob = model.predict(val_gen, steps=validation_steps, verbose=0)
        y_val_pred = (y_val_pred_prob > 0.5).astype(int).ravel()
        y_val_true = val_fold['label'].astype(int).values

        precision = precision_score(y_val_true, y_val_pred, average='binary')
        recall = recall_score(y_val_true, y_val_pred, average='binary')
        f1 = f1_score(y_val_true, y_val_pred, average='binary')

        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

        print("\nValidation Metrics:")
        print(f"Accuracy: {val_acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

        fold_no += 1

    mean_acc = np.mean(accuracy_list)
    mean_precision = np.mean(precision_list)
    mean_recall = np.mean(recall_list)
    mean_f1 = np.mean(f1_list)

    print("\n5-Fold CV Metrics:")
    print(f"Mean Accuracy: {mean_acc:.4f}")
    print(f"Mean Precision: {mean_precision:.4f}")
    print(f"Mean Recall: {mean_recall:.4f}")
    print(f"Mean F1-Score: {mean_f1:.4f}")

    return mean_acc, mean_precision, mean_recall, mean_f1

# %%
#############################################
# 5) 5-Fold Cross-Validation'ı Çalıştır
#############################################
mean_acc, mean_precision, mean_recall, mean_f1 = run_5fold_cv(df_trainVal, n_splits=n_splits, epochs=epochs, batch_size=batch_size)
print(f"\nFinal Results:\nAccuracy = {mean_acc:.4f}, Precision = {mean_precision:.4f}, Recall = {mean_recall:.4f}, F1-Score = {mean_f1:.4f}")
# Out:
# === Fold 1/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 94s 7s/step - accuracy: 0.5490 - loss: 0.7571 - val_accuracy: 0.7209 - val_loss: 0.5507
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7438 - loss: 0.5169 - val_accuracy: 0.7674 - val_loss: 0.5014
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7230 - loss: 0.5731 - val_accuracy: 0.7907 - val_loss: 0.4675
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8097 - loss: 0.5051 - val_accuracy: 0.8372 - val_loss: 0.4329
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8159 - loss: 0.4185 - val_accuracy: 0.7907 - val_loss: 0.4094
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8068 - loss: 0.4032 - val_accuracy: 0.8605 - val_loss: 0.3903
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7983 - loss: 0.3938 - val_accuracy: 0.8837 - val_loss: 0.3723
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8326 - loss: 0.3759 - val_accuracy: 0.8837 - val_loss: 0.3624
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8445 - loss: 0.3534 - val_accuracy: 0.8837 - val_loss: 0.3547
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8028 - loss: 0.3454 - val_accuracy: 0.9070 - val_loss: 0.3415
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8956 - loss: 0.2864 - val_accuracy: 0.9302 - val_loss: 0.3292
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9227 - loss: 0.2799 - val_accuracy: 0.9302 - val_loss: 0.3240
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8784 - loss: 0.2936 - val_accuracy: 0.9302 - val_loss: 0.3187
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9351 - loss: 0.2770 - val_accuracy: 0.9302 - val_loss: 0.3117
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.8773 - loss: 0.3061 - val_accuracy: 0.9302 - val_loss: 0.3040
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.9068 - loss: 0.2369 - val_accuracy: 0.9070 - val_loss: 0.3062
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8928 - loss: 0.2754 - val_accuracy: 0.9070 - val_loss: 0.2966
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9064 - loss: 0.2705 - val_accuracy: 0.9302 - val_loss: 0.2920
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.9169 - loss: 0.2291 - val_accuracy: 0.9302 - val_loss: 0.2877
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8841 - loss: 0.2437 - val_accuracy: 0.9302 - val_loss: 0.2837
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8755 - loss: 0.2698 - val_accuracy: 0.9302 - val_loss: 0.2736
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8851 - loss: 0.2722 - val_accuracy: 0.9070 - val_loss: 0.2898
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9176 - loss: 0.2181 - val_accuracy: 0.9070 - val_loss: 0.2883
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8916 - loss: 0.2556 - val_accuracy: 0.9302 - val_loss: 0.2706
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.9125 - loss: 0.2210 - val_accuracy: 0.9302 - val_loss: 0.2626
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9302, Precision: 0.6765, Recall: 0.7419, F1-Score: 0.7077
#
# === Fold 2/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 62s 6s/step - accuracy: 0.5655 - loss: 0.7764 - val_accuracy: 0.7209 - val_loss: 0.5754
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.7452 - loss: 0.6274 - val_accuracy: 0.7209 - val_loss: 0.5741
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7191 - loss: 0.6143 - val_accuracy: 0.7209 - val_loss: 0.5161
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.6841 - loss: 0.6324 - val_accuracy: 0.7209 - val_loss: 0.4792
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7265 - loss: 0.4881 - val_accuracy: 0.7907 - val_loss: 0.4555
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7774 - loss: 0.4707 - val_accuracy: 0.7674 - val_loss: 0.4261
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7644 - loss: 0.4649 - val_accuracy: 0.7674 - val_loss: 0.4081
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8109 - loss: 0.3766 - val_accuracy: 0.7674 - val_loss: 0.3938
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7673 - loss: 0.4174 - val_accuracy: 0.7907 - val_loss: 0.3681
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8051 - loss: 0.3788 - val_accuracy: 0.8605 - val_loss: 0.3424
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8789 - loss: 0.3203 - val_accuracy: 0.8605 - val_loss: 0.3233
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.8337 - loss: 0.3240 - val_accuracy: 0.8605 - val_loss: 0.3064
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.9049 - loss: 0.2878 - val_accuracy: 0.9070 - val_loss: 0.2912
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8913 - loss: 0.2679 - val_accuracy: 0.9070 - val_loss: 0.2828
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8598 - loss: 0.2955 - val_accuracy: 0.8605 - val_loss: 0.2768
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7840 - loss: 0.4041 - val_accuracy: 0.8605 - val_loss: 0.2737
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.9101 - loss: 0.2540 - val_accuracy: 0.9302 - val_loss: 0.2535
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.9008 - loss: 0.2592 - val_accuracy: 0.9535 - val_loss: 0.2326
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8617 - loss: 0.3426 - val_accuracy: 0.9302 - val_loss: 0.2300
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9313 - loss: 0.2199 - val_accuracy: 0.9302 - val_loss: 0.2330
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.9090 - loss: 0.2470 - val_accuracy: 0.9302 - val_loss: 0.2270
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.9168 - loss: 0.2229 - val_accuracy: 0.9302 - val_loss: 0.2111
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8932 - loss: 0.2451 - val_accuracy: 0.9767 - val_loss: 0.1923
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8645 - loss: 0.2917 - val_accuracy: 0.9535 - val_loss: 0.1896
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9103 - loss: 0.2241 - val_accuracy: 0.9535 - val_loss: 0.1856
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9535, Precision: 0.6667, Recall: 0.7097, F1-Score: 0.6875
#
# === Fold 3/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.4911 - loss: 0.8173 - val_accuracy: 0.7209 - val_loss: 0.5511
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.6997 - loss: 0.6216 - val_accuracy: 0.7209 - val_loss: 0.5445
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.6967 - loss: 0.6076 - val_accuracy: 0.7209 - val_loss: 0.4824
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7421 - loss: 0.4964 - val_accuracy: 0.7209 - val_loss: 0.4388
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8542 - loss: 0.3863 - val_accuracy: 0.7442 - val_loss: 0.4223
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.7858 - loss: 0.4279 - val_accuracy: 0.7442 - val_loss: 0.4169
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7127 - loss: 0.4887 - val_accuracy: 0.7209 - val_loss: 0.4147
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7962 - loss: 0.4359 - val_accuracy: 0.7209 - val_loss: 0.3984
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.7793 - loss: 0.4241 - val_accuracy: 0.7907 - val_loss: 0.3641
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7759 - loss: 0.4204 - val_accuracy: 0.7674 - val_loss: 0.3646
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8672 - loss: 0.3486 - val_accuracy: 0.7907 - val_loss: 0.3455
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8416 - loss: 0.3420 - val_accuracy: 0.7907 - val_loss: 0.3306
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8518 - loss: 0.3178 - val_accuracy: 0.7674 - val_loss: 0.3287
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8702 - loss: 0.2950 - val_accuracy: 0.8372 - val_loss: 0.2929
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9012 - loss: 0.2873 - val_accuracy: 0.8605 - val_loss: 0.2825
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.8168 - loss: 0.3345 - val_accuracy: 0.8372 - val_loss: 0.2918
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.8629 - loss: 0.2749 - val_accuracy: 0.8372 - val_loss: 0.2891
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8711 - loss: 0.3131 - val_accuracy: 0.8605 - val_loss: 0.2667
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8669 - loss: 0.2893 - val_accuracy: 0.8837 - val_loss: 0.2538
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8305 - loss: 0.3478 - val_accuracy: 0.9070 - val_loss: 0.2380
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8868 - loss: 0.2636 - val_accuracy: 0.9070 - val_loss: 0.2289
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8616 - loss: 0.2672 - val_accuracy: 0.9070 - val_loss: 0.2139
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8370 - loss: 0.3043 - val_accuracy: 0.9070 - val_loss: 0.2031
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.8695 - loss: 0.2693 - val_accuracy: 0.9070 - val_loss: 0.2068
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.8946 - loss: 0.2584 - val_accuracy: 0.9070 - val_loss: 0.2055
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9070, Precision: 0.7143, Recall: 0.8065, F1-Score: 0.7576
#
# === Fold 4/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.5643 - loss: 0.7551 - val_accuracy: 0.7209 - val_loss: 0.5672
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7301 - loss: 0.6013 - val_accuracy: 0.7209 - val_loss: 0.5339
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.7772 - loss: 0.4855 - val_accuracy: 0.7907 - val_loss: 0.4840
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.7866 - loss: 0.4093 - val_accuracy: 0.7907 - val_loss: 0.4637
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.7681 - loss: 0.4882 - val_accuracy: 0.7907 - val_loss: 0.4731
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7955 - loss: 0.3787 - val_accuracy: 0.7907 - val_loss: 0.4647
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7422 - loss: 0.4604 - val_accuracy: 0.7907 - val_loss: 0.4226
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8094 - loss: 0.3728 - val_accuracy: 0.7907 - val_loss: 0.4176
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8074 - loss: 0.3811 - val_accuracy: 0.7907 - val_loss: 0.4375
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7890 - loss: 0.4105 - val_accuracy: 0.7907 - val_loss: 0.4185
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8324 - loss: 0.3584 - val_accuracy: 0.7907 - val_loss: 0.4041
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8752 - loss: 0.3073 - val_accuracy: 0.7907 - val_loss: 0.3854
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8939 - loss: 0.3081 - val_accuracy: 0.7907 - val_loss: 0.3771
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.8923 - loss: 0.2949 - val_accuracy: 0.7907 - val_loss: 0.3680
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8954 - loss: 0.2606 - val_accuracy: 0.7907 - val_loss: 0.3669
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8819 - loss: 0.3375 - val_accuracy: 0.7907 - val_loss: 0.3434
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8635 - loss: 0.2848 - val_accuracy: 0.8140 - val_loss: 0.3215
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8698 - loss: 0.2918 - val_accuracy: 0.8605 - val_loss: 0.3022
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.8891 - loss: 0.3150 - val_accuracy: 0.8372 - val_loss: 0.3126
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.8820 - loss: 0.2468 - val_accuracy: 0.8140 - val_loss: 0.3276
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.8994 - loss: 0.2235 - val_accuracy: 0.8605 - val_loss: 0.2999
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9587 - loss: 0.1977 - val_accuracy: 0.9070 - val_loss: 0.2707
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.9211 - loss: 0.2467 - val_accuracy: 0.8837 - val_loss: 0.2809
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8818 - loss: 0.2484 - val_accuracy: 0.8605 - val_loss: 0.2856
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9173 - loss: 0.1910 - val_accuracy: 0.9070 - val_loss: 0.2689
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9070, Precision: 0.7143, Recall: 0.8065, F1-Score: 0.7576
#
# === Fold 5/5 ===
# Found 172 validated image filenames belonging to 2 classes.
# Found 42 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 6s/step - accuracy: 0.4876 - loss: 0.7963 - val_accuracy: 0.7381 - val_loss: 0.4857
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7020 - loss: 0.6136 - val_accuracy: 0.7381 - val_loss: 0.4531
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.7399 - loss: 0.5335 - val_accuracy: 0.8095 - val_loss: 0.4217
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.7420 - loss: 0.4444 - val_accuracy: 0.8333 - val_loss: 0.4076
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8176 - loss: 0.4125 - val_accuracy: 0.8333 - val_loss: 0.3822
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7469 - loss: 0.4568 - val_accuracy: 0.8333 - val_loss: 0.3568
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.7493 - loss: 0.4412 - val_accuracy: 0.8333 - val_loss: 0.3384
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8433 - loss: 0.3565 - val_accuracy: 0.8571 - val_loss: 0.3223
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8793 - loss: 0.3102 - val_accuracy: 0.8810 - val_loss: 0.3083
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8446 - loss: 0.3173 - val_accuracy: 0.8810 - val_loss: 0.2965
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7713 - loss: 0.4486 - val_accuracy: 0.9048 - val_loss: 0.2839
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8937 - loss: 0.2844 - val_accuracy: 0.8810 - val_loss: 0.2727
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.8585 - loss: 0.2807 - val_accuracy: 0.8810 - val_loss: 0.2636
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8478 - loss: 0.2968 - val_accuracy: 0.9048 - val_loss: 0.2537
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8976 - loss: 0.2804 - val_accuracy: 0.9762 - val_loss: 0.2483
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8814 - loss: 0.2789 - val_accuracy: 0.9762 - val_loss: 0.2400
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8858 - loss: 0.2875 - val_accuracy: 0.9524 - val_loss: 0.2295
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8676 - loss: 0.2769 - val_accuracy: 0.9524 - val_loss: 0.2234
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.9122 - loss: 0.2747 - val_accuracy: 0.9762 - val_loss: 0.2162
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8822 - loss: 0.2889 - val_accuracy: 1.0000 - val_loss: 0.2115
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.9281 - loss: 0.2078 - val_accuracy: 1.0000 - val_loss: 0.2035
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9007 - loss: 0.2142 - val_accuracy: 1.0000 - val_loss: 0.1942
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8530 - loss: 0.3446 - val_accuracy: 1.0000 - val_loss: 0.1954
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.9231 - loss: 0.2229 - val_accuracy: 1.0000 - val_loss: 0.1848
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8841 - loss: 0.2743 - val_accuracy: 0.9762 - val_loss: 0.1777
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9762, Precision: 0.6875, Recall: 0.7097, F1-Score: 0.6984
#
# 5-Fold CV Metrics:
# Mean Accuracy: 0.9348
# Mean Precision: 0.6918
# Mean Recall: 0.7548
# Mean F1-Score: 0.7218
#
# Final Results:
# Accuracy = 0.9348, Precision = 0.6918, Recall = 0.7548, F1-Score = 0.7218
