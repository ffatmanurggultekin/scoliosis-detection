# %% [markdown]
# <a href="https://colab.research.google.com/github/ffatmanurggultekin/scoliosis-detection/blob/main/densenet_201_no_mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os
import time  # Zaman ölçümü için
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from google.colab import drive

# Google Drive'ı bağla
drive.mount('/content/drive')

# Veri yolları
train_dir = '/content/drive/MyDrive/ham_veri/train'
test_dir = '/content/drive/MyDrive/ham_veri/test'

# Veri toplama fonksiyonu
def gather_paths_and_labels(directory):
    data = []
    for label, class_name in enumerate(['Normal', 'Scol']):
        class_dir = os.path.join(directory, class_name)
        for file in os.listdir(class_dir):
            data.append((os.path.join(class_dir, file), label))
    return np.array(data)

# Verileri yükleme
train_data = gather_paths_and_labels(train_dir)
test_data = gather_paths_and_labels(test_dir)

# Class Weights
class_weights_dict = {0: 1.0, 1: 0.7}
print(f"\nUpdated Class Weights: {class_weights_dict}")

# Veri artırma (Data Augmentation)
train_datagen = ImageDataGenerator(
    rescale=1./255, rotation_range=15, width_shift_range=0.2,
    height_shift_range=0.2, zoom_range=[0.8, 1.2], horizontal_flip=True
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# DenseNet201 Modeli
def create_densenet201_model():
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

    for layer in base_model.layers[:-10]:  # Son 10 katman dışında tümünü dondur
        layer.trainable = False
    for layer in base_model.layers[-10:]:
        layer.trainable = True

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=base_model.input, outputs=output)
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])
    return model

# Cross-Validation Süresi ve Train Accuracy Ölçümü
def run_cross_validation(data, n_splits=5, epochs=50, batch_size=32):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    accuracy_list, fold_times = [], []

    total_start_time = time.time()  # ⏳ Cross-validation süresini başlat

    for fold, (train_idx, val_idx) in enumerate(skf.split(data[:, 0], data[:, 1])):
        print(f"\n=== Fold {fold + 1}/{n_splits} ===")

        fold_start_time = time.time()

        train_files, val_files = data[train_idx], data[val_idx]
        train_df = pd.DataFrame({'filename': train_files[:, 0], 'class': train_files[:, 1]})
        val_df = pd.DataFrame({'filename': val_files[:, 0], 'class': val_files[:, 1]})

        train_gen = train_datagen.flow_from_dataframe(
            train_df, x_col='filename', y_col='class',
            target_size=(224, 224), batch_size=batch_size, class_mode='binary', shuffle=True
        )

        val_gen = val_test_datagen.flow_from_dataframe(
            val_df, x_col='filename', y_col='class',
            target_size=(224, 224), batch_size=batch_size, class_mode='binary', shuffle=False
        )

        model = create_densenet201_model()
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        model.fit(train_gen, validation_data=val_gen, epochs=epochs, callbacks=[early_stopping], class_weight=class_weights_dict, verbose=1)

        fold_end_time = time.time()
        fold_time = fold_end_time - fold_start_time
        fold_times.append(fold_time)

        print(f"Fold {fold + 1} eğitim süresi: {fold_time:.2f} saniye")

        val_labels = val_files[:, 1].astype(int)
        val_probs = model.predict(val_gen).ravel()
        val_preds = (val_probs > 0.5).astype(int)
        accuracy = accuracy_score(val_labels, val_preds)

        accuracy_list.append(accuracy)

    total_end_time = time.time()
    total_cv_time = total_end_time - total_start_time

    mean_train_acc = np.mean(accuracy_list)
    std_train_acc = np.std(accuracy_list)

    print(f"\n⏳ Toplam Cross-Validation Süresi: {total_cv_time:.2f} saniye")
    print(f"Train Accuracy: {mean_train_acc:.4f} ± {std_train_acc:.4f}")

    return total_cv_time, mean_train_acc, std_train_acc

# Final Model Eğitimi ve Test Değerlendirme
def evaluate_final_model(model, test_data):
    test_df = pd.DataFrame({'filename': test_data[:, 0], 'class': test_data[:, 1]})
    test_gen = val_test_datagen.flow_from_dataframe(
        test_df, x_col='filename', y_col='class',
        target_size=(224, 224), batch_size=32, class_mode='binary', shuffle=False
    )

    test_labels = test_data[:, 1].astype(int)
    test_probs = model.predict(test_gen).ravel()
    test_preds = (test_probs > 0.5).astype(int)

    test_accuracy = accuracy_score(test_labels, test_preds)
    test_f1 = f1_score(test_labels, test_preds)
    test_precision = precision_score(test_labels, test_preds)
    test_recall = recall_score(test_labels, test_preds)

    cm = confusion_matrix(test_labels, test_preds)

    print("\n=== Final Model Test Sonuçları ===")
    print(f"Test Accuracy: {test_accuracy:.4f}")
    print(f"Test F1 Score: {test_f1:.4f}")
    print(f"Test Precision: {test_precision:.4f}")
    print(f"Test Recall: {test_recall:.4f}")

    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Normal", "Scol"], yticklabels=["Normal", "Scol"])
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix - Final Model")
    plt.show()

    return test_accuracy, test_f1, test_precision, test_recall

# Model Eğitimi
cv_time, mean_train_acc, std_train_acc = run_cross_validation(train_data, n_splits=5, epochs=50, batch_size=32)
final_model = create_densenet201_model()
final_model.fit(train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='binary'), epochs=50)
test_acc, test_f1, test_precision, test_recall = evaluate_final_model(final_model, test_data)

# Sonuçları Yazdırma
print("\n=== Sonuçlar ===")
print(f"Toplam Hesaplama Süresi: {cv_time:.2f} saniye")
print(f"Train Accuracy: {mean_train_acc:.4f} ± {std_train_acc:.4f}")
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test F1 Score: {test_f1:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
# Out:
# Mounted at /content/drive
#
# Updated Class Weights: {0: 1.0, 1: 0.7}
#
# === Fold 1/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 127s 18s/step - accuracy: 0.2770 - loss: 1.0765 - val_accuracy: 0.6111 - val_loss: 0.6706
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - accuracy: 0.7056 - loss: 0.4646 - val_accuracy: 0.7500 - val_loss: 0.5362
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 441ms/step - accuracy: 0.7338 - loss: 0.4599 - val_accuracy: 0.7500 - val_loss: 0.5322
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 451ms/step - accuracy: 0.7891 - loss: 0.4540 - val_accuracy: 0.7778 - val_loss: 0.4925
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 451ms/step - accuracy: 0.7434 - loss: 0.4067 - val_accuracy: 0.7500 - val_loss: 0.4547
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.7565 - loss: 0.4101 - val_accuracy: 0.7778 - val_loss: 0.4340
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 472ms/step - accuracy: 0.7885 - loss: 0.3416 - val_accuracy: 0.7778 - val_loss: 0.4094
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 453ms/step - accuracy: 0.8299 - loss: 0.3014 - val_accuracy: 0.7778 - val_loss: 0.3876
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 457ms/step - accuracy: 0.8985 - loss: 0.2488 - val_accuracy: 0.8056 - val_loss: 0.3671
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 510ms/step - accuracy: 0.7840 - loss: 0.3274 - val_accuracy: 0.8333 - val_loss: 0.3551
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 513ms/step - accuracy: 0.8524 - loss: 0.2551 - val_accuracy: 0.8333 - val_loss: 0.3434
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - accuracy: 0.8644 - loss: 0.2519 - val_accuracy: 0.8056 - val_loss: 0.3296
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 454ms/step - accuracy: 0.8951 - loss: 0.1972 - val_accuracy: 0.8611 - val_loss: 0.2978
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 434ms/step - accuracy: 0.9466 - loss: 0.2060 - val_accuracy: 0.8889 - val_loss: 0.2658
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 505ms/step - accuracy: 0.9585 - loss: 0.1477 - val_accuracy: 0.9167 - val_loss: 0.2417
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 503ms/step - accuracy: 0.9396 - loss: 0.1806 - val_accuracy: 0.9444 - val_loss: 0.2272
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - accuracy: 0.9384 - loss: 0.1850 - val_accuracy: 0.9167 - val_loss: 0.2141
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 457ms/step - accuracy: 0.9415 - loss: 0.1651 - val_accuracy: 0.9167 - val_loss: 0.2002
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.9604 - loss: 0.1491 - val_accuracy: 0.9167 - val_loss: 0.1778
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 469ms/step - accuracy: 0.9469 - loss: 0.1363 - val_accuracy: 0.9167 - val_loss: 0.1657
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 511ms/step - accuracy: 0.9458 - loss: 0.1319 - val_accuracy: 0.9167 - val_loss: 0.1583
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - accuracy: 0.9439 - loss: 0.1255 - val_accuracy: 0.9167 - val_loss: 0.1536
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 507ms/step - accuracy: 0.9786 - loss: 0.1005 - val_accuracy: 0.9167 - val_loss: 0.1523
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 443ms/step - accuracy: 0.9488 - loss: 0.1101 - val_accuracy: 0.9167 - val_loss: 0.1466
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 448ms/step - accuracy: 0.9822 - loss: 0.0943 - val_accuracy: 0.9167 - val_loss: 0.1400
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 527ms/step - accuracy: 0.9731 - loss: 0.0918 - val_accuracy: 0.9444 - val_loss: 0.1291
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 463ms/step - accuracy: 0.9875 - loss: 0.0724 - val_accuracy: 0.9444 - val_loss: 0.1233
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.9823 - loss: 0.0672 - val_accuracy: 0.9444 - val_loss: 0.1192
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - accuracy: 0.9394 - loss: 0.0873 - val_accuracy: 0.9444 - val_loss: 0.1225
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 447ms/step - accuracy: 0.9962 - loss: 0.0657 - val_accuracy: 0.9444 - val_loss: 0.1170
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 449ms/step - accuracy: 0.9621 - loss: 0.0723 - val_accuracy: 0.9444 - val_loss: 0.1090
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 501ms/step - accuracy: 0.9810 - loss: 0.0625 - val_accuracy: 0.9444 - val_loss: 0.1082
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 392ms/step - accuracy: 0.9848 - loss: 0.0547 - val_accuracy: 0.9444 - val_loss: 0.1213
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 405ms/step - accuracy: 0.9939 - loss: 0.0514 - val_accuracy: 0.9444 - val_loss: 0.1312
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 383ms/step - accuracy: 0.9857 - loss: 0.0456 - val_accuracy: 0.9444 - val_loss: 0.1250
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 382ms/step - accuracy: 0.9863 - loss: 0.0511 - val_accuracy: 0.9444 - val_loss: 0.1206
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 444ms/step - accuracy: 0.9977 - loss: 0.0340 - val_accuracy: 0.9444 - val_loss: 0.1218
# Fold 1 eğitim süresi: 224.49 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 39s 20s/step
#
# === Fold 2/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 88s 11s/step - accuracy: 0.5399 - loss: 0.5760 - val_accuracy: 0.7500 - val_loss: 0.5168
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.6869 - loss: 0.5262 - val_accuracy: 0.8056 - val_loss: 0.4646
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.7450 - loss: 0.4242 - val_accuracy: 0.7778 - val_loss: 0.4369
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 527ms/step - accuracy: 0.7794 - loss: 0.3582 - val_accuracy: 0.7500 - val_loss: 0.4150
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 442ms/step - accuracy: 0.7759 - loss: 0.3505 - val_accuracy: 0.8056 - val_loss: 0.3923
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 526ms/step - accuracy: 0.8382 - loss: 0.2992 - val_accuracy: 0.8611 - val_loss: 0.3703
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 456ms/step - accuracy: 0.8397 - loss: 0.2909 - val_accuracy: 0.8611 - val_loss: 0.3484
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 441ms/step - accuracy: 0.8649 - loss: 0.2693 - val_accuracy: 0.8611 - val_loss: 0.3275
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 527ms/step - accuracy: 0.8655 - loss: 0.2844 - val_accuracy: 0.9167 - val_loss: 0.3071
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 452ms/step - accuracy: 0.8866 - loss: 0.2283 - val_accuracy: 0.9444 - val_loss: 0.2874
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - accuracy: 0.8512 - loss: 0.2400 - val_accuracy: 0.9444 - val_loss: 0.2667
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - accuracy: 0.9276 - loss: 0.1779 - val_accuracy: 0.9444 - val_loss: 0.2467
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 524ms/step - accuracy: 0.9561 - loss: 0.1481 - val_accuracy: 0.9444 - val_loss: 0.2299
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 463ms/step - accuracy: 0.9470 - loss: 0.1623 - val_accuracy: 0.9444 - val_loss: 0.2124
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 464ms/step - accuracy: 0.9112 - loss: 0.1709 - val_accuracy: 0.9722 - val_loss: 0.1955
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 461ms/step - accuracy: 0.8835 - loss: 0.1957 - val_accuracy: 0.9722 - val_loss: 0.1770
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 460ms/step - accuracy: 0.9489 - loss: 0.1203 - val_accuracy: 0.9722 - val_loss: 0.1609
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.9818 - loss: 0.0988 - val_accuracy: 0.9722 - val_loss: 0.1478
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 482ms/step - accuracy: 0.9636 - loss: 0.1115 - val_accuracy: 0.9722 - val_loss: 0.1362
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - accuracy: 0.9337 - loss: 0.1450 - val_accuracy: 0.9722 - val_loss: 0.1263
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - accuracy: 0.9683 - loss: 0.1037 - val_accuracy: 0.9722 - val_loss: 0.1170
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - accuracy: 0.9840 - loss: 0.0877 - val_accuracy: 0.9722 - val_loss: 0.1100
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 517ms/step - accuracy: 0.9954 - loss: 0.0730 - val_accuracy: 0.9722 - val_loss: 0.1054
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 446ms/step - accuracy: 0.9553 - loss: 0.1127 - val_accuracy: 0.9722 - val_loss: 0.1035
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 472ms/step - accuracy: 0.9808 - loss: 0.0740 - val_accuracy: 0.9722 - val_loss: 0.1024
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 453ms/step - accuracy: 0.9685 - loss: 0.0769 - val_accuracy: 0.9722 - val_loss: 0.1010
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 384ms/step - accuracy: 0.9919 - loss: 0.0551 - val_accuracy: 0.9722 - val_loss: 0.1018
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 383ms/step - accuracy: 0.9805 - loss: 0.0912 - val_accuracy: 0.9722 - val_loss: 0.1027
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 391ms/step - accuracy: 0.9954 - loss: 0.0416 - val_accuracy: 0.9722 - val_loss: 0.1075
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 384ms/step - accuracy: 0.9939 - loss: 0.0491 - val_accuracy: 0.9722 - val_loss: 0.1068
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 396ms/step - accuracy: 1.0000 - loss: 0.0478 - val_accuracy: 0.9722 - val_loss: 0.1025
# Fold 2 eğitim süresi: 159.36 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 36s 18s/step
#
# === Fold 3/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 91s 12s/step - accuracy: 0.7272 - loss: 0.4554 - val_accuracy: 0.7222 - val_loss: 0.5676
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 465ms/step - accuracy: 0.7457 - loss: 0.4053 - val_accuracy: 0.8333 - val_loss: 0.5289
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 452ms/step - accuracy: 0.7611 - loss: 0.3791 - val_accuracy: 0.8611 - val_loss: 0.4577
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 447ms/step - accuracy: 0.7814 - loss: 0.3889 - val_accuracy: 0.8889 - val_loss: 0.4118
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 467ms/step - accuracy: 0.7887 - loss: 0.3545 - val_accuracy: 0.8889 - val_loss: 0.3645
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 466ms/step - accuracy: 0.8192 - loss: 0.3221 - val_accuracy: 0.8889 - val_loss: 0.3296
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 476ms/step - accuracy: 0.8759 - loss: 0.2825 - val_accuracy: 0.9167 - val_loss: 0.3056
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 458ms/step - accuracy: 0.8326 - loss: 0.2739 - val_accuracy: 0.9167 - val_loss: 0.2854
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - accuracy: 0.7796 - loss: 0.3115 - val_accuracy: 0.9167 - val_loss: 0.2711
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 510ms/step - accuracy: 0.8740 - loss: 0.2333 - val_accuracy: 0.9167 - val_loss: 0.2565
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 456ms/step - accuracy: 0.8868 - loss: 0.2167 - val_accuracy: 0.9444 - val_loss: 0.2432
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 465ms/step - accuracy: 0.9239 - loss: 0.1938 - val_accuracy: 0.9444 - val_loss: 0.2298
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 444ms/step - accuracy: 0.9197 - loss: 0.2014 - val_accuracy: 0.9722 - val_loss: 0.2165
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 503ms/step - accuracy: 0.9441 - loss: 0.1783 - val_accuracy: 0.9722 - val_loss: 0.2035
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 467ms/step - accuracy: 0.9313 - loss: 0.1662 - val_accuracy: 1.0000 - val_loss: 0.1898
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 532ms/step - accuracy: 0.9094 - loss: 0.2008 - val_accuracy: 1.0000 - val_loss: 0.1794
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 460ms/step - accuracy: 0.9253 - loss: 0.1763 - val_accuracy: 0.9722 - val_loss: 0.1651
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 513ms/step - accuracy: 0.9638 - loss: 0.1466 - val_accuracy: 0.9444 - val_loss: 0.1542
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 522ms/step - accuracy: 0.9330 - loss: 0.1549 - val_accuracy: 0.9444 - val_loss: 0.1434
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 520ms/step - accuracy: 0.9821 - loss: 0.1123 - val_accuracy: 0.9722 - val_loss: 0.1311
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 436ms/step - accuracy: 0.9725 - loss: 0.1006 - val_accuracy: 0.9722 - val_loss: 0.1217
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.9191 - loss: 0.1522 - val_accuracy: 0.9722 - val_loss: 0.1119
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 465ms/step - accuracy: 0.9719 - loss: 0.1031 - val_accuracy: 0.9722 - val_loss: 0.1029
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - accuracy: 0.9680 - loss: 0.0964 - val_accuracy: 0.9444 - val_loss: 0.1007
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 449ms/step - accuracy: 0.9606 - loss: 0.0921 - val_accuracy: 0.9722 - val_loss: 0.0929
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 454ms/step - accuracy: 0.9609 - loss: 0.1016 - val_accuracy: 0.9722 - val_loss: 0.0841
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 473ms/step - accuracy: 0.9756 - loss: 0.0979 - val_accuracy: 0.9722 - val_loss: 0.0792
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 543ms/step - accuracy: 0.9564 - loss: 0.0785 - val_accuracy: 0.9722 - val_loss: 0.0779
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step - accuracy: 0.9867 - loss: 0.0586 - val_accuracy: 0.9722 - val_loss: 0.0802
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 457ms/step - accuracy: 0.9442 - loss: 0.0901 - val_accuracy: 0.9722 - val_loss: 0.0810
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 483ms/step - accuracy: 0.9939 - loss: 0.0570 - val_accuracy: 0.9722 - val_loss: 0.0761
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 481ms/step - accuracy: 0.9920 - loss: 0.0574 - val_accuracy: 0.9722 - val_loss: 0.0743
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 479ms/step - accuracy: 0.9863 - loss: 0.0554 - val_accuracy: 0.9722 - val_loss: 0.0720
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 541ms/step - accuracy: 0.9962 - loss: 0.0383 - val_accuracy: 0.9722 - val_loss: 0.0718
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step - accuracy: 0.9941 - loss: 0.0357 - val_accuracy: 0.9722 - val_loss: 0.0713
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 474ms/step - accuracy: 0.9882 - loss: 0.0605 - val_accuracy: 0.9722 - val_loss: 0.0696
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 1.0000 - loss: 0.0491 - val_accuracy: 0.9722 - val_loss: 0.0682
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 412ms/step - accuracy: 0.9772 - loss: 0.0480 - val_accuracy: 0.9722 - val_loss: 0.0683
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 411ms/step - accuracy: 0.9941 - loss: 0.0216 - val_accuracy: 0.9722 - val_loss: 0.0691
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 464ms/step - accuracy: 0.9848 - loss: 0.0529 - val_accuracy: 0.9722 - val_loss: 0.0701
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 391ms/step - accuracy: 0.9977 - loss: 0.0386 - val_accuracy: 0.9722 - val_loss: 0.0691
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 469ms/step - accuracy: 0.9946 - loss: 0.0534 - val_accuracy: 0.9722 - val_loss: 0.0682
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 390ms/step - accuracy: 1.0000 - loss: 0.0294 - val_accuracy: 0.9722 - val_loss: 0.0714
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 384ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 0.9722 - val_loss: 0.0754
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 0.9831 - loss: 0.0311 - val_accuracy: 0.9722 - val_loss: 0.0732
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 468ms/step - accuracy: 0.9765 - loss: 0.0504 - val_accuracy: 0.9722 - val_loss: 0.0650
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 514ms/step - accuracy: 0.9906 - loss: 0.0251 - val_accuracy: 0.9722 - val_loss: 0.0622
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - accuracy: 1.0000 - loss: 0.0282 - val_accuracy: 0.9722 - val_loss: 0.0636
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 386ms/step - accuracy: 0.9962 - loss: 0.0246 - val_accuracy: 0.9722 - val_loss: 0.0664
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 445ms/step - accuracy: 1.0000 - loss: 0.0243 - val_accuracy: 0.9722 - val_loss: 0.0730
# Fold 3 eğitim süresi: 205.99 saniye
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7aff9bff2700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 17s 18s/step
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7aff9bff2700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 35s 18s/step
#
# === Fold 4/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 92s 12s/step - accuracy: 0.4261 - loss: 0.6445 - val_accuracy: 0.7222 - val_loss: 0.5432
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 453ms/step - accuracy: 0.7218 - loss: 0.4767 - val_accuracy: 0.7222 - val_loss: 0.4876
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - accuracy: 0.7064 - loss: 0.5208 - val_accuracy: 0.7500 - val_loss: 0.4369
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 458ms/step - accuracy: 0.7116 - loss: 0.4914 - val_accuracy: 0.8333 - val_loss: 0.4021
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - accuracy: 0.7675 - loss: 0.3448 - val_accuracy: 0.8889 - val_loss: 0.3714
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - accuracy: 0.7834 - loss: 0.3464 - val_accuracy: 0.8889 - val_loss: 0.3434
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 466ms/step - accuracy: 0.7794 - loss: 0.3502 - val_accuracy: 0.8889 - val_loss: 0.3193
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 451ms/step - accuracy: 0.8523 - loss: 0.2489 - val_accuracy: 0.8889 - val_loss: 0.2963
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 444ms/step - accuracy: 0.8342 - loss: 0.2804 - val_accuracy: 0.8889 - val_loss: 0.2762
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 464ms/step - accuracy: 0.8539 - loss: 0.2582 - val_accuracy: 0.8889 - val_loss: 0.2602
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - accuracy: 0.8615 - loss: 0.2576 - val_accuracy: 0.9167 - val_loss: 0.2390
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 464ms/step - accuracy: 0.9127 - loss: 0.2113 - val_accuracy: 0.9444 - val_loss: 0.2201
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 446ms/step - accuracy: 0.9232 - loss: 0.2076 - val_accuracy: 0.9444 - val_loss: 0.2013
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 463ms/step - accuracy: 0.9329 - loss: 0.1683 - val_accuracy: 0.9444 - val_loss: 0.1868
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 463ms/step - accuracy: 0.9302 - loss: 0.1663 - val_accuracy: 0.9444 - val_loss: 0.1717
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 440ms/step - accuracy: 0.9459 - loss: 0.1504 - val_accuracy: 0.9444 - val_loss: 0.1569
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 468ms/step - accuracy: 0.9564 - loss: 0.1522 - val_accuracy: 0.9722 - val_loss: 0.1413
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 454ms/step - accuracy: 0.9422 - loss: 0.1604 - val_accuracy: 0.9722 - val_loss: 0.1297
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.9667 - loss: 0.1178 - val_accuracy: 0.9722 - val_loss: 0.1197
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 449ms/step - accuracy: 0.9762 - loss: 0.1013 - val_accuracy: 1.0000 - val_loss: 0.1101
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 503ms/step - accuracy: 0.9604 - loss: 0.1124 - val_accuracy: 1.0000 - val_loss: 0.1023
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.9782 - loss: 0.0940 - val_accuracy: 1.0000 - val_loss: 0.0957
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 462ms/step - accuracy: 0.9865 - loss: 0.0963 - val_accuracy: 1.0000 - val_loss: 0.0891
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 533ms/step - accuracy: 0.9790 - loss: 0.0990 - val_accuracy: 1.0000 - val_loss: 0.0825
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 523ms/step - accuracy: 1.0000 - loss: 0.0703 - val_accuracy: 1.0000 - val_loss: 0.0777
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.9737 - loss: 0.0917 - val_accuracy: 1.0000 - val_loss: 0.0742
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 533ms/step - accuracy: 0.9697 - loss: 0.1082 - val_accuracy: 1.0000 - val_loss: 0.0706
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 477ms/step - accuracy: 0.9750 - loss: 0.0709 - val_accuracy: 1.0000 - val_loss: 0.0662
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 530ms/step - accuracy: 0.9730 - loss: 0.0661 - val_accuracy: 1.0000 - val_loss: 0.0631
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 448ms/step - accuracy: 0.9787 - loss: 0.0588 - val_accuracy: 1.0000 - val_loss: 0.0608
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 464ms/step - accuracy: 0.9903 - loss: 0.0512 - val_accuracy: 1.0000 - val_loss: 0.0562
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 456ms/step - accuracy: 0.9889 - loss: 0.0485 - val_accuracy: 1.0000 - val_loss: 0.0526
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 465ms/step - accuracy: 0.9915 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.0509
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.9919 - loss: 0.0391 - val_accuracy: 1.0000 - val_loss: 0.0491
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 521ms/step - accuracy: 1.0000 - loss: 0.0344 - val_accuracy: 1.0000 - val_loss: 0.0477
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 455ms/step - accuracy: 0.9977 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0471
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 454ms/step - accuracy: 1.0000 - loss: 0.0279 - val_accuracy: 1.0000 - val_loss: 0.0456
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 479ms/step - accuracy: 1.0000 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0447
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.9906 - loss: 0.0467 - val_accuracy: 1.0000 - val_loss: 0.0434
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 454ms/step - accuracy: 1.0000 - loss: 0.0286 - val_accuracy: 1.0000 - val_loss: 0.0420
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 453ms/step - accuracy: 0.9977 - loss: 0.0237 - val_accuracy: 1.0000 - val_loss: 0.0417
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 454ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0412
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 1.0000 - loss: 0.0226 - val_accuracy: 0.9722 - val_loss: 0.0412
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 0.9962 - loss: 0.0312 - val_accuracy: 0.9722 - val_loss: 0.0422
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 388ms/step - accuracy: 0.9954 - loss: 0.0351 - val_accuracy: 0.9722 - val_loss: 0.0419
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 460ms/step - accuracy: 0.9778 - loss: 0.0429 - val_accuracy: 0.9722 - val_loss: 0.0400
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 530ms/step - accuracy: 1.0000 - loss: 0.0163 - val_accuracy: 0.9722 - val_loss: 0.0387
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 385ms/step - accuracy: 0.9761 - loss: 0.0479 - val_accuracy: 0.9722 - val_loss: 0.0422
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 398ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.9722 - val_loss: 0.0455
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 397ms/step - accuracy: 0.9977 - loss: 0.0210 - val_accuracy: 0.9722 - val_loss: 0.0444
# Fold 4 eğitim süresi: 208.69 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 39s 21s/step
#
# === Fold 5/5 ===
# Found 144 validated image filenames belonging to 2 classes.
# Found 36 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 101s 14s/step - accuracy: 0.6343 - loss: 0.5388 - val_accuracy: 0.8056 - val_loss: 0.5472
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 0.6992 - loss: 0.4559 - val_accuracy: 0.7778 - val_loss: 0.4789
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step - accuracy: 0.7428 - loss: 0.4680 - val_accuracy: 0.8056 - val_loss: 0.4556
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 484ms/step - accuracy: 0.6864 - loss: 0.4249 - val_accuracy: 0.8611 - val_loss: 0.4485
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 486ms/step - accuracy: 0.7779 - loss: 0.3449 - val_accuracy: 0.8611 - val_loss: 0.4149
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 539ms/step - accuracy: 0.8279 - loss: 0.3057 - val_accuracy: 0.8889 - val_loss: 0.3746
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 494ms/step - accuracy: 0.8546 - loss: 0.2627 - val_accuracy: 0.9167 - val_loss: 0.3481
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.8777 - loss: 0.2515 - val_accuracy: 0.9444 - val_loss: 0.3287
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 525ms/step - accuracy: 0.8984 - loss: 0.2524 - val_accuracy: 0.9444 - val_loss: 0.3051
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 551ms/step - accuracy: 0.8982 - loss: 0.2501 - val_accuracy: 0.9444 - val_loss: 0.2824
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 481ms/step - accuracy: 0.8669 - loss: 0.2678 - val_accuracy: 0.9444 - val_loss: 0.2532
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - accuracy: 0.8831 - loss: 0.2245 - val_accuracy: 0.9722 - val_loss: 0.2272
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 483ms/step - accuracy: 0.8900 - loss: 0.2442 - val_accuracy: 0.9722 - val_loss: 0.2041
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 0.9504 - loss: 0.1837 - val_accuracy: 1.0000 - val_loss: 0.1928
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 484ms/step - accuracy: 0.9235 - loss: 0.1792 - val_accuracy: 1.0000 - val_loss: 0.1736
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 489ms/step - accuracy: 0.9456 - loss: 0.1944 - val_accuracy: 1.0000 - val_loss: 0.1530
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 0.8867 - loss: 0.1826 - val_accuracy: 1.0000 - val_loss: 0.1328
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 467ms/step - accuracy: 0.9301 - loss: 0.1821 - val_accuracy: 1.0000 - val_loss: 0.1214
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 471ms/step - accuracy: 0.9044 - loss: 0.1808 - val_accuracy: 1.0000 - val_loss: 0.1094
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 482ms/step - accuracy: 0.9597 - loss: 0.1046 - val_accuracy: 1.0000 - val_loss: 0.0967
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 487ms/step - accuracy: 0.9605 - loss: 0.1215 - val_accuracy: 1.0000 - val_loss: 0.0922
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 499ms/step - accuracy: 0.9631 - loss: 0.1050 - val_accuracy: 1.0000 - val_loss: 0.0844
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 537ms/step - accuracy: 0.9779 - loss: 0.0977 - val_accuracy: 1.0000 - val_loss: 0.0782
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 416ms/step - accuracy: 0.9500 - loss: 0.1050 - val_accuracy: 0.9722 - val_loss: 0.0792
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 539ms/step - accuracy: 0.9565 - loss: 0.0860 - val_accuracy: 0.9722 - val_loss: 0.0758
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 485ms/step - accuracy: 0.9962 - loss: 0.0685 - val_accuracy: 1.0000 - val_loss: 0.0691
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 481ms/step - accuracy: 0.9719 - loss: 0.1211 - val_accuracy: 1.0000 - val_loss: 0.0643
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 478ms/step - accuracy: 0.9895 - loss: 0.0685 - val_accuracy: 1.0000 - val_loss: 0.0618
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 486ms/step - accuracy: 0.9700 - loss: 0.0855 - val_accuracy: 1.0000 - val_loss: 0.0511
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 536ms/step - accuracy: 0.9860 - loss: 0.0558 - val_accuracy: 1.0000 - val_loss: 0.0465
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 497ms/step - accuracy: 1.0000 - loss: 0.0444 - val_accuracy: 1.0000 - val_loss: 0.0435
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 468ms/step - accuracy: 0.9566 - loss: 0.0977 - val_accuracy: 1.0000 - val_loss: 0.0445
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 412ms/step - accuracy: 0.9640 - loss: 0.0838 - val_accuracy: 1.0000 - val_loss: 0.0450
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step - accuracy: 1.0000 - loss: 0.0440 - val_accuracy: 1.0000 - val_loss: 0.0408
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 539ms/step - accuracy: 0.9779 - loss: 0.0757 - val_accuracy: 1.0000 - val_loss: 0.0379
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 404ms/step - accuracy: 0.9714 - loss: 0.0794 - val_accuracy: 1.0000 - val_loss: 0.0381
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 486ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0354
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 535ms/step - accuracy: 0.9906 - loss: 0.0416 - val_accuracy: 1.0000 - val_loss: 0.0326
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 470ms/step - accuracy: 0.9941 - loss: 0.0487 - val_accuracy: 1.0000 - val_loss: 0.0313
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 469ms/step - accuracy: 0.9964 - loss: 0.0418 - val_accuracy: 1.0000 - val_loss: 0.0293
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 543ms/step - accuracy: 0.9903 - loss: 0.0311 - val_accuracy: 1.0000 - val_loss: 0.0276
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 476ms/step - accuracy: 0.9813 - loss: 0.0364 - val_accuracy: 1.0000 - val_loss: 0.0260
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 469ms/step - accuracy: 0.9920 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 0.0248
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 459ms/step - accuracy: 0.9511 - loss: 0.0890 - val_accuracy: 1.0000 - val_loss: 0.0257
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 406ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0254
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 401ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0252
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 500ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0245
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 500ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0232
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 483ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0225
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 488ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0215
# Fold 5 eğitim süresi: 221.32 saniye
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 38s 19s/step
#
# ⏳ Toplam Cross-Validation Süresi: 1207.50 saniye
# Train Accuracy: 0.9722 ± 0.0176
# Found 180 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 77s 6s/step - accuracy: 0.6654 - loss: 0.5991
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 362ms/step - accuracy: 0.7400 - loss: 0.4986
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 407ms/step - accuracy: 0.8057 - loss: 0.4344
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 0.8320 - loss: 0.3783
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 0.7847 - loss: 0.3810
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 365ms/step - accuracy: 0.9099 - loss: 0.3091
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.8345 - loss: 0.3294
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 0.8788 - loss: 0.3097
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 382ms/step - accuracy: 0.8889 - loss: 0.2923
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 366ms/step - accuracy: 0.8785 - loss: 0.2695
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 0.8909 - loss: 0.2620
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 0.9240 - loss: 0.2194
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 0.9528 - loss: 0.1900
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 0.9656 - loss: 0.1684
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 0.9466 - loss: 0.1846
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 0.9517 - loss: 0.1540
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 0.9742 - loss: 0.1441
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 408ms/step - accuracy: 0.9515 - loss: 0.1276
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 382ms/step - accuracy: 0.9793 - loss: 0.1018
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 388ms/step - accuracy: 0.9503 - loss: 0.1469
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 0.9832 - loss: 0.0945
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 0.9854 - loss: 0.0885
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 0.9768 - loss: 0.1084
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 380ms/step - accuracy: 0.9598 - loss: 0.1169
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.9791 - loss: 0.0924
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 0.9803 - loss: 0.0832
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 367ms/step - accuracy: 0.9719 - loss: 0.0743
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 0.9730 - loss: 0.1194
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 419ms/step - accuracy: 0.9829 - loss: 0.0707
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 359ms/step - accuracy: 0.9871 - loss: 0.0760
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 398ms/step - accuracy: 0.9918 - loss: 0.0467
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 403ms/step - accuracy: 0.9921 - loss: 0.0402
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 0.9768 - loss: 0.0572
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 0.9881 - loss: 0.0415
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 0.9945 - loss: 0.0293
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 0.9902 - loss: 0.0326
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 0.9974 - loss: 0.0434
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 0.0218
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 1.0000 - loss: 0.0218
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 370ms/step - accuracy: 1.0000 - loss: 0.0180
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 1.0000 - loss: 0.0164
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 379ms/step - accuracy: 1.0000 - loss: 0.0285
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 415ms/step - accuracy: 0.9974 - loss: 0.0170
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 374ms/step - accuracy: 0.9878 - loss: 0.0335
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 369ms/step - accuracy: 0.9975 - loss: 0.0247
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 364ms/step - accuracy: 1.0000 - loss: 0.0249
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 373ms/step - accuracy: 1.0000 - loss: 0.0224
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 413ms/step - accuracy: 1.0000 - loss: 0.0142
# Found 79 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 52s 17s/step
#
# === Final Model Test Sonuçları ===
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# Test Precision: 1.0000
# Test Recall: 1.0000
# === Sonuçlar ===
# Toplam Hesaplama Süresi: 1207.50 saniye
# Train Accuracy: 0.9722 ± 0.0176
# Test Accuracy: 1.0000
# Test F1 Score: 1.0000
# Test Precision: 1.0000
# Test Recall: 1.0000
