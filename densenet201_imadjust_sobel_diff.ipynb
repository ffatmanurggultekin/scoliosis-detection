# %% [markdown]
# <a href="https://colab.research.google.com/github/ffatmanurggultekin/scoliosis-detection/blob/main/densenet201_imadjust_sobel_diff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#############################################
# 1) Klasör Yolları ve Ayarlar
#############################################
train_dir = "/content/drive/MyDrive/train_imadjust_sobel_diff"
val_dir = "/content/drive/MyDrive/validation_imadjust_sobel_diff"

batch_size = 32
epochs = 50
n_splits = 5  # Cross-validation kat sayısı

# %%
#############################################
# 2) Veri Yollarını ve Etiketlerini Toplama
#############################################
def gather_paths_and_labels(dir_path):
    filepaths = []
    labels = []

    normal_path = os.path.join(dir_path, "Normal")
    scol_path = os.path.join(dir_path, "Scol")

    if os.path.exists(normal_path):
        for fname in os.listdir(normal_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(normal_path, fname))
                labels.append(0)  # Normal => 0

    if os.path.exists(scol_path):
        for fname in os.listdir(scol_path):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                filepaths.append(os.path.join(scol_path, fname))
                labels.append(1)  # Scol => 1

    return pd.DataFrame({'filepath': filepaths, 'label': labels})

# Train ve Validation'dan gelen DataFrame'leri birleştirelim
df_train = gather_paths_and_labels(train_dir)
df_val = gather_paths_and_labels(val_dir)
df_trainVal = pd.concat([df_train, df_val], ignore_index=True)

# Label sütununu string formatına çevir
df_trainVal['label'] = df_trainVal['label'].astype(str)

print(f"Train+Validation birleşik boyutu: {len(df_trainVal)}")
# Out:
# Train+Validation birleşik boyutu: 214

# %%
#############################################
# 3) DenseNet201 Modelini Oluşturma
#############################################
def create_densenet201_model():
    base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    for layer in base_model.layers:
        layer.trainable = False  # Fine-tuning yapmayacaksanız dondurun

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    output = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs=base_model.input, outputs=output)
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
#############################################
# 4) Cross-Validation Fonksiyonu
#############################################
def run_5fold_cv(df, n_splits=5, epochs=50, batch_size=32):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    X = df['filepath'].values
    y = df['label'].values

    accuracy_list = []
    precision_list = []
    recall_list = []
    f1_list = []
    fold_no = 1

    # Data Augmentation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    val_datagen = ImageDataGenerator(rescale=1./255)

    for train_idx, val_idx in skf.split(X, y):
        print(f"\n=== Fold {fold_no}/{n_splits} ===")

        # Fold için Train/Validation veri setlerini ayır
        train_fold = df.iloc[train_idx]
        val_fold = df.iloc[val_idx]

        # Data generator'lar
        train_gen = train_datagen.flow_from_dataframe(
            train_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )
        val_gen = val_datagen.flow_from_dataframe(
            val_fold,
            x_col='filepath',
            y_col='label',
            target_size=(224, 224),
            batch_size=batch_size,
            class_mode='binary'
        )

        # Modeli oluştur
        model = create_densenet201_model()

        # EarlyStopping
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        steps_per_epoch = math.ceil(len(train_fold) / batch_size)
        validation_steps = math.ceil(len(val_fold) / batch_size)

        # Modeli eğit
        history = model.fit(
            train_gen,
            epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            validation_data=val_gen,
            validation_steps=validation_steps,
            callbacks=[early_stopping],
            verbose=1
        )

        # Validation setinde değerlendirme
        val_loss, val_acc = model.evaluate(val_gen, steps=validation_steps, verbose=0)
        accuracy_list.append(val_acc)

        # Confusion Matrix ve Classification Report
        y_val_pred_prob = model.predict(val_gen, steps=validation_steps, verbose=0)
        y_val_pred = (y_val_pred_prob > 0.5).astype(int).ravel()
        y_val_true = val_fold['label'].astype(int).values

        precision = precision_score(y_val_true, y_val_pred, average='binary')
        recall = recall_score(y_val_true, y_val_pred, average='binary')
        f1 = f1_score(y_val_true, y_val_pred, average='binary')

        precision_list.append(precision)
        recall_list.append(recall)
        f1_list.append(f1)

        print("\nValidation Metrics:")
        print(f"Accuracy: {val_acc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")

        fold_no += 1

    mean_acc = np.mean(accuracy_list)
    mean_precision = np.mean(precision_list)
    mean_recall = np.mean(recall_list)
    mean_f1 = np.mean(f1_list)

    print("\n5-Fold CV Metrics:")
    print(f"Mean Accuracy: {mean_acc:.4f}")
    print(f"Mean Precision: {mean_precision:.4f}")
    print(f"Mean Recall: {mean_recall:.4f}")
    print(f"Mean F1-Score: {mean_f1:.4f}")

    return mean_acc, mean_precision, mean_recall, mean_f1

# %%
#############################################
# 5) 5-Fold Cross-Validation'ı Çalıştır
#############################################
mean_acc, mean_precision, mean_recall, mean_f1 = run_5fold_cv(df_trainVal, n_splits=n_splits, epochs=epochs, batch_size=batch_size)
print(f"\nFinal Results:\nAccuracy = {mean_acc:.4f}, Precision = {mean_precision:.4f}, Recall = {mean_recall:.4f}, F1-Score = {mean_f1:.4f}")
# Out:
# === Fold 1/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 98s 8s/step - accuracy: 0.3927 - loss: 0.9345 - val_accuracy: 0.7209 - val_loss: 0.5773
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7131 - loss: 0.6159 - val_accuracy: 0.7209 - val_loss: 0.5696
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7260 - loss: 0.5809 - val_accuracy: 0.7209 - val_loss: 0.5224
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.7271 - loss: 0.5740 - val_accuracy: 0.7442 - val_loss: 0.4700
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7329 - loss: 0.5073 - val_accuracy: 0.7442 - val_loss: 0.4366
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.7438 - loss: 0.5110 - val_accuracy: 0.7442 - val_loss: 0.4155
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.7718 - loss: 0.4457 - val_accuracy: 0.7442 - val_loss: 0.4109
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.8010 - loss: 0.3770 - val_accuracy: 0.7442 - val_loss: 0.4104
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8579 - loss: 0.3510 - val_accuracy: 0.7442 - val_loss: 0.4031
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8152 - loss: 0.4077 - val_accuracy: 0.7442 - val_loss: 0.3779
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8330 - loss: 0.3547 - val_accuracy: 0.7442 - val_loss: 0.3564
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8727 - loss: 0.3369 - val_accuracy: 0.7442 - val_loss: 0.3572
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.8681 - loss: 0.3127 - val_accuracy: 0.7442 - val_loss: 0.3454
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8572 - loss: 0.3080 - val_accuracy: 0.8140 - val_loss: 0.3163
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8470 - loss: 0.3076 - val_accuracy: 0.8140 - val_loss: 0.2997
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8817 - loss: 0.3132 - val_accuracy: 0.8140 - val_loss: 0.2955
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.8493 - loss: 0.2983 - val_accuracy: 0.8140 - val_loss: 0.3066
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8581 - loss: 0.3140 - val_accuracy: 0.8140 - val_loss: 0.3015
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.8863 - loss: 0.2900 - val_accuracy: 0.8140 - val_loss: 0.2875
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8747 - loss: 0.2749 - val_accuracy: 0.8140 - val_loss: 0.2680
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.9192 - loss: 0.2508 - val_accuracy: 0.8605 - val_loss: 0.2453
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.9043 - loss: 0.3156 - val_accuracy: 0.8605 - val_loss: 0.2407
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8982 - loss: 0.2862 - val_accuracy: 0.8372 - val_loss: 0.2489
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9129 - loss: 0.2314 - val_accuracy: 0.8372 - val_loss: 0.2510
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8436 - loss: 0.3246 - val_accuracy: 0.8837 - val_loss: 0.2192
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.8837, Precision: 0.7222, Recall: 0.8387, F1-Score: 0.7761
#
# === Fold 2/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.4155 - loss: 0.9878 - val_accuracy: 0.6512 - val_loss: 0.6192
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.6990 - loss: 0.6751 - val_accuracy: 0.7209 - val_loss: 0.5756
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.6901 - loss: 0.6548 - val_accuracy: 0.7209 - val_loss: 0.5457
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7515 - loss: 0.5260 - val_accuracy: 0.7209 - val_loss: 0.5108
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7717 - loss: 0.4833 - val_accuracy: 0.6977 - val_loss: 0.4928
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7299 - loss: 0.5298 - val_accuracy: 0.7209 - val_loss: 0.4633
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.7446 - loss: 0.4819 - val_accuracy: 0.7674 - val_loss: 0.4484
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8288 - loss: 0.4360 - val_accuracy: 0.7674 - val_loss: 0.4340
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.7716 - loss: 0.4590 - val_accuracy: 0.7674 - val_loss: 0.4103
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8210 - loss: 0.3600 - val_accuracy: 0.7674 - val_loss: 0.3929
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7788 - loss: 0.3817 - val_accuracy: 0.8140 - val_loss: 0.3721
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8084 - loss: 0.3837 - val_accuracy: 0.8372 - val_loss: 0.3547
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8504 - loss: 0.3103 - val_accuracy: 0.8605 - val_loss: 0.3413
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8228 - loss: 0.3473 - val_accuracy: 0.8605 - val_loss: 0.3334
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.7945 - loss: 0.4204 - val_accuracy: 0.8837 - val_loss: 0.3173
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8446 - loss: 0.4074 - val_accuracy: 0.9070 - val_loss: 0.2973
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8914 - loss: 0.2866 - val_accuracy: 0.9070 - val_loss: 0.2879
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9039 - loss: 0.2552 - val_accuracy: 0.9302 - val_loss: 0.2777
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9059 - loss: 0.2410 - val_accuracy: 0.9302 - val_loss: 0.2659
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.9046 - loss: 0.2699 - val_accuracy: 0.9302 - val_loss: 0.2636
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8611 - loss: 0.2710 - val_accuracy: 0.9070 - val_loss: 0.2690
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9146 - loss: 0.2525 - val_accuracy: 0.9302 - val_loss: 0.2567
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9235 - loss: 0.2516 - val_accuracy: 0.9302 - val_loss: 0.2510
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8915 - loss: 0.2394 - val_accuracy: 0.9302 - val_loss: 0.2390
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9076 - loss: 0.2220 - val_accuracy: 0.9302 - val_loss: 0.2411
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9302, Precision: 0.7353, Recall: 0.8065, F1-Score: 0.7692
#
# === Fold 3/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 68s 6s/step - accuracy: 0.4731 - loss: 0.7982 - val_accuracy: 0.7209 - val_loss: 0.6250
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.6809 - loss: 0.6310 - val_accuracy: 0.7209 - val_loss: 0.6027
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7406 - loss: 0.5410 - val_accuracy: 0.7209 - val_loss: 0.5582
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7726 - loss: 0.4539 - val_accuracy: 0.6977 - val_loss: 0.5338
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.7523 - loss: 0.4634 - val_accuracy: 0.7209 - val_loss: 0.5179
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8113 - loss: 0.4105 - val_accuracy: 0.7209 - val_loss: 0.5243
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8003 - loss: 0.3985 - val_accuracy: 0.7209 - val_loss: 0.5181
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8153 - loss: 0.3709 - val_accuracy: 0.7209 - val_loss: 0.4735
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8650 - loss: 0.3101 - val_accuracy: 0.7209 - val_loss: 0.4574
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9005 - loss: 0.2874 - val_accuracy: 0.7209 - val_loss: 0.4495
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.7475 - loss: 0.4230 - val_accuracy: 0.7442 - val_loss: 0.4310
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8196 - loss: 0.3481 - val_accuracy: 0.7209 - val_loss: 0.4335
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8503 - loss: 0.3320 - val_accuracy: 0.7209 - val_loss: 0.4179
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8693 - loss: 0.3101 - val_accuracy: 0.7674 - val_loss: 0.4071
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.8467 - loss: 0.3182 - val_accuracy: 0.7674 - val_loss: 0.3836
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8665 - loss: 0.2818 - val_accuracy: 0.7907 - val_loss: 0.3711
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8607 - loss: 0.2989 - val_accuracy: 0.7674 - val_loss: 0.3777
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.8555 - loss: 0.2864 - val_accuracy: 0.7674 - val_loss: 0.3836
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8967 - loss: 0.2752 - val_accuracy: 0.7907 - val_loss: 0.3531
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.8923 - loss: 0.2623 - val_accuracy: 0.8372 - val_loss: 0.3360
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8917 - loss: 0.2941 - val_accuracy: 0.8605 - val_loss: 0.3246
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.8530 - loss: 0.3162 - val_accuracy: 0.8605 - val_loss: 0.3160
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9314 - loss: 0.2327 - val_accuracy: 0.8837 - val_loss: 0.3061
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8796 - loss: 0.2638 - val_accuracy: 0.9767 - val_loss: 0.2804
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.8977 - loss: 0.2386 - val_accuracy: 0.9535 - val_loss: 0.2762
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9535, Precision: 0.7576, Recall: 0.8065, F1-Score: 0.7812
#
# === Fold 4/5 ===
# Found 171 validated image filenames belonging to 2 classes.
# Found 43 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 64s 6s/step - accuracy: 0.3661 - loss: 1.0728 - val_accuracy: 0.7209 - val_loss: 0.5679
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6971 - loss: 0.5735 - val_accuracy: 0.7209 - val_loss: 0.6928
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7343 - loss: 0.6179 - val_accuracy: 0.7209 - val_loss: 0.6662
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.7152 - loss: 0.5936 - val_accuracy: 0.7209 - val_loss: 0.5594
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.7570 - loss: 0.5044 - val_accuracy: 0.7209 - val_loss: 0.4652
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.7727 - loss: 0.4711 - val_accuracy: 0.7674 - val_loss: 0.4312
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.7683 - loss: 0.4335 - val_accuracy: 0.7442 - val_loss: 0.4310
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8153 - loss: 0.3792 - val_accuracy: 0.7209 - val_loss: 0.4388
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8588 - loss: 0.3225 - val_accuracy: 0.7209 - val_loss: 0.4489
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8657 - loss: 0.3348 - val_accuracy: 0.7674 - val_loss: 0.4198
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8138 - loss: 0.3689 - val_accuracy: 0.7674 - val_loss: 0.4087
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8039 - loss: 0.3760 - val_accuracy: 0.7674 - val_loss: 0.3927
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8409 - loss: 0.3455 - val_accuracy: 0.7674 - val_loss: 0.3821
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.8495 - loss: 0.3177 - val_accuracy: 0.7907 - val_loss: 0.3687
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - accuracy: 0.8044 - loss: 0.3629 - val_accuracy: 0.7907 - val_loss: 0.3606
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8707 - loss: 0.2895 - val_accuracy: 0.7907 - val_loss: 0.3700
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - accuracy: 0.8794 - loss: 0.3044 - val_accuracy: 0.7907 - val_loss: 0.3597
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8802 - loss: 0.3014 - val_accuracy: 0.8140 - val_loss: 0.3402
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - accuracy: 0.8594 - loss: 0.2935 - val_accuracy: 0.8372 - val_loss: 0.3146
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.8617 - loss: 0.2975 - val_accuracy: 0.8372 - val_loss: 0.3049
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8603 - loss: 0.2996 - val_accuracy: 0.8372 - val_loss: 0.3036
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8379 - loss: 0.3047 - val_accuracy: 0.8372 - val_loss: 0.2994
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8920 - loss: 0.2413 - val_accuracy: 0.8605 - val_loss: 0.2693
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8903 - loss: 0.2774 - val_accuracy: 0.8605 - val_loss: 0.2637
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.8924 - loss: 0.2668 - val_accuracy: 0.9302 - val_loss: 0.2493
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9302, Precision: 0.7059, Recall: 0.7742, F1-Score: 0.7385
#
# === Fold 5/5 ===
# Found 172 validated image filenames belonging to 2 classes.
# Found 42 validated image filenames belonging to 2 classes.
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 70s 6s/step - accuracy: 0.5811 - loss: 0.6726 - val_accuracy: 0.7381 - val_loss: 0.5110
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 3/50
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7313 - loss: 0.5469 - val_accuracy: 0.7381 - val_loss: 0.4776
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8029 - loss: 0.4986 - val_accuracy: 0.7619 - val_loss: 0.4500
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.7576 - loss: 0.5083 - val_accuracy: 0.7857 - val_loss: 0.4240
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8126 - loss: 0.3976 - val_accuracy: 0.8333 - val_loss: 0.4041
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.7110 - loss: 0.4620 - val_accuracy: 0.8571 - val_loss: 0.3885
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - accuracy: 0.8437 - loss: 0.3860 - val_accuracy: 0.8571 - val_loss: 0.3723
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.7612 - loss: 0.4345 - val_accuracy: 0.8333 - val_loss: 0.3523
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8522 - loss: 0.3330 - val_accuracy: 0.8810 - val_loss: 0.3429
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8790 - loss: 0.2878 - val_accuracy: 0.8810 - val_loss: 0.3334
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 154ms/step - accuracy: 0.8090 - loss: 0.3576 - val_accuracy: 0.8810 - val_loss: 0.3194
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - accuracy: 0.8577 - loss: 0.3037 - val_accuracy: 0.8810 - val_loss: 0.3028
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.8533 - loss: 0.3107 - val_accuracy: 0.8810 - val_loss: 0.2978
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.8870 - loss: 0.3014 - val_accuracy: 0.8810 - val_loss: 0.2914
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.8863 - loss: 0.2880 - val_accuracy: 0.8810 - val_loss: 0.2885
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.8384 - loss: 0.3032 - val_accuracy: 0.9048 - val_loss: 0.2710
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step - accuracy: 0.8756 - loss: 0.3196 - val_accuracy: 0.9048 - val_loss: 0.2610
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - accuracy: 0.9009 - loss: 0.2570 - val_accuracy: 0.9048 - val_loss: 0.2566
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - accuracy: 0.9419 - loss: 0.2337 - val_accuracy: 0.9048 - val_loss: 0.2530
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 155ms/step - accuracy: 0.9178 - loss: 0.2402 - val_accuracy: 0.9048 - val_loss: 0.2483
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8991 - loss: 0.2590 - val_accuracy: 0.9048 - val_loss: 0.2526
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - accuracy: 0.9426 - loss: 0.2128 - val_accuracy: 0.9048 - val_loss: 0.2374
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.9247 - loss: 0.2671 - val_accuracy: 0.9524 - val_loss: 0.2237
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.9567 - loss: 0.2131 - val_accuracy: 0.9286 - val_loss: 0.2219
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9320 - loss: 0.2180 - val_accuracy: 0.9286 - val_loss: 0.2194
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
#
# Validation Metrics:
# Accuracy: 0.9286, Precision: 0.7059, Recall: 0.7742, F1-Score: 0.7385
#
# 5-Fold CV Metrics:
# Mean Accuracy: 0.9252
# Mean Precision: 0.7254
# Mean Recall: 0.8000
# Mean F1-Score: 0.7607
#
# Final Results:
# Accuracy = 0.9252, Precision = 0.7254, Recall = 0.8000, F1-Score = 0.7607
